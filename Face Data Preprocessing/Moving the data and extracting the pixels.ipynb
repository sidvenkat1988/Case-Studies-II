# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# %cd Face\ Dataset
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset

# %%
# !ls
# Out:
# '1-Gathering Face Data.ipynb'	     Augmented_Images   name.npy
# '2-Data Pre-Processing.ipynb'	     final_face_data    shortened_image_set.npy
# '3-Data Augmentation.ipynb'	     image_path.npy     shortened_name_set.npy
# '4-Final Data Preprocessing.ipynb'   lfw	        Untitled0.ipynb

# %%
# %cd final_face_data/
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset/final_face_data

# %%
# !ls
# Out:
# haarcascade_eye.xml		     testing.csv
# haarcascade_frontalface_default.xml  training.csv

# %%
import pandas as pd
import shutil
import os

# %%
pd.set_option('max_colwidth', -1)

# %%
training_df = pd.read_csv('training.csv')
testing_df = pd.read_csv('testing.csv')

# %% [markdown]
# # Moving the training data

# %%
training_df
# Out:
#        Unnamed: 0  ...               label
# 0      0           ...  George_HW_Bush
# 1      1           ...  Tom_Cruise
# 2      2           ...  Sergey_Lavrov
# 3      3           ...  Tony_Blair
# 4      4           ...  Thomas_OBrien
# ...   ..           ...             ...
# 42495  42495       ...  Silvio_Berlusconi
# 42496  42496       ...  Mahathir_Mohamad
# 42497  42497       ...  Jacques_Chirac
# 42498  42498       ...  Kofi_Annan
# 42499  42499       ...  Michael_Bloomberg
#
# [42500 rows x 3 columns]

# %%
training_df['image_type'] = training_df['image_path'].str.split('/').str[-2]
training_df['image_name'] = training_df['image_path'].str.split('/').str[-1]
training_df['concatenated_image_name'] = training_df['image_type'] + '-' + training_df['image_name']
training_df.head()
# Out:
#    Unnamed: 0  ...                                concatenated_image_name
# 0  0           ...  zca_height_horizontal-George_HW_Bush - _0_2673.jpg
# 1  1           ...  fs_width_rotation_horizontal-Tom_Cruise - _0_2144.jpg
# 2  2           ...  zca_with_rotation-Sergey_Lavrov - _0_1073.jpg
# 3  3           ...  fs_shear_horizontal-Tony_Blair - _0_9892.jpg
# 4  4           ...  zca_with_rotation-Thomas_OBrien - _0_5583.jpg
#
# [5 rows x 6 columns]

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       'Data Augmentation'
# '2-Gathering files information.ipynb'  'Face Dataset'
# '3-Data Pre-Processing.ipynb'	        Final_Face_Dataset
# '4-Gathering Raw Waveforms.ipynb'       mel_spectrograms
# '5-Concatenating Raw Waveforms.ipynb'   raw_data

# %%
# %cd Final_Face_Dataset/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# !ls
# Out:
# testing_set  training_set

# %%
# %cd training_set/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %%
training_path = os.getcwd()

# %%
training_df.head()
# Out:
#    Unnamed: 0  ...                                concatenated_image_name
# 0  0           ...  zca_height_horizontal-George_HW_Bush - _0_2673.jpg
# 1  1           ...  fs_width_rotation_horizontal-Tom_Cruise - _0_2144.jpg
# 2  2           ...  zca_with_rotation-Sergey_Lavrov - _0_1073.jpg
# 3  3           ...  fs_shear_horizontal-Tony_Blair - _0_9892.jpg
# 4  4           ...  zca_with_rotation-Thomas_OBrien - _0_5583.jpg
#
# [5 rows x 6 columns]

# %%
new_path = []
for i in range(len(training_df)):
  path = os.path.join(training_path, training_df['concatenated_image_name'][i])
  new_path.append(path)
training_df['new_path'] = new_path
training_df.head()
# Out:
#    Unnamed: 0  ...                                                                                                                      new_path
# 0  0           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/zca_height_horizontal-George_HW_Bush - _0_2673.jpg
# 1  1           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/fs_width_rotation_horizontal-Tom_Cruise - _0_2144.jpg
# 2  2           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/zca_with_rotation-Sergey_Lavrov - _0_1073.jpg
# 3  3           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/fs_shear_horizontal-Tony_Blair - _0_9892.jpg
# 4  4           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/zca_with_rotation-Thomas_OBrien - _0_5583.jpg
#
# [5 rows x 7 columns]

# %%
for i in range(len(training_df)):
  try:
    shutil.move(training_df['image_path'][i], training_df['new_path'][i])
  except Exception as e:
    pass

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %% [markdown]
# # Moving the test set

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd testing_set/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set

# %%
testing_path = os.getcwd()

# %%
testing_df.head()
# Out:
#    Unnamed: 0  ...                   label
# 0  0           ...  Megawati_Sukarnoputri
# 1  1           ...  Jennifer_Garner
# 2  2           ...  Guillermo_Coria
# 3  3           ...  Mohammed_Al
# 4  4           ...  Jeremy_Greenstock
#
# [5 rows x 3 columns]

# %%
testing_df['image_type'] = testing_df['image_path'].str.split('/').str[-2]
testing_df['image_name'] = testing_df['image_path'].str.split('/').str[-1]
testing_df['concatenated_image_name'] = testing_df['image_type'] + '-' + testing_df['image_name']
testing_df.head()
# Out:
#    Unnamed: 0  ...                                      concatenated_image_name
# 0  0           ...  zca_with_rotation-Megawati_Sukarnoputri - _0_9267.jpg
# 1  1           ...  fs_zoom_horizontal-Jennifer_Garner - _0_4355.jpg
# 2  2           ...  fs_height_rotation_horizontal-Guillermo_Coria - _0_2301.jpg
# 3  3           ...  zca_shear_horizontal-Mohammed_Al-Douri - _0_444.jpg
# 4  4           ...  zca_with_rotation-Jeremy_Greenstock - _0_6483.jpg
#
# [5 rows x 6 columns]

# %%
new_path = []
for i in range(len(testing_df)):
  path = os.path.join(testing_path, testing_df['concatenated_image_name'][i])
  new_path.append(path)
testing_df['new_path'] = new_path
testing_df.head()
# Out:
#    Unnamed: 0  ...                                                                                                                           new_path
# 0  0           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/zca_with_rotation-Megawati_Sukarnoputri - _0_9267.jpg
# 1  1           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/fs_zoom_horizontal-Jennifer_Garner - _0_4355.jpg
# 2  2           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/fs_height_rotation_horizontal-Guillermo_Coria - _0_2301.jpg
# 3  3           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/zca_shear_horizontal-Mohammed_Al-Douri - _0_444.jpg
# 4  4           ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/zca_with_rotation-Jeremy_Greenstock - _0_6483.jpg
#
# [5 rows x 7 columns]

# %%
for i in range(len(testing_df)):
  try:
    shutil.move(testing_df['image_path'][i], testing_df['new_path'][i])
  except Exception as e:
    pass

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set

# %%
len(os.listdir(os.getcwd()))
# Out:
# 10341

# %%
len(testing_df)
# Out:
# 10370

# %% [markdown]
# # Making up the numbers

# %% [markdown]
# As a result of some mistakes done earlier while transferring the training and testing images to the new folders, there was a loss in data due to similar image names across different augmentation types performed earlier. Hence, this action is performed to make up for the mismatch in numbers.

# %% [markdown]
# # Making up for test set

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set

# %%
images = []
for i in os.listdir(os.getcwd()):
  images.append(i)
columns = ['images']
new_testing_df = pd.DataFrame(columns = columns)
new_testing_df['images'] = images
new_testing_df.head()
# Out:
#                          images
# 0  Vaclav_Havel - _0_2174.jpg
# 1  Vaclav_Havel - _0_2744.jpg
# 2  George_Clooney - _0_7911.jpg
# 3  Paul_ONeill - _0_286.jpg
# 4  Paul_ONeill - _0_1622.jpg

# %%
new_testing_df['label'] = new_testing_df['images'].str.split('-').str[0]
new_testing_df.head()
# Out:
#                          images            label
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel
# 2  George_Clooney - _0_7911.jpg  George_Clooney
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill
# 4  Paul_ONeill - _0_1622.jpg     Paul_ONeill

# %%
new_testing_df['label_count'] = new_testing_df['label'].map(new_testing_df['label'].value_counts(dropna=False))
new_testing_df.head()
# Out:
#                          images            label  label_count
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel     61
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel     61
# 2  George_Clooney - _0_7911.jpg  George_Clooney   61
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill      61
# 4  Paul_ONeill - _0_1622.jpg     Paul_ONeill      61

# %%
label = new_testing_df.loc[new_testing_df['label_count']<61]['label'].unique()

# %%
label
# Out:
# array(['Thomas_OBrien ', 'Mohammad_Khatami ', 'Muhammad_Ali ',
#        'Sergey_Lavrov ', 'Tom_Hanks ', 'Jiri_Novak ', 'James_Kelly ',
#        'Queen_Elizabeth_II ', 'George_HW_Bush ', 'Wen_Jiabao ',
#        'James_Blake ', 'Joe_Lieberman ', 'Charles_Moose ',
#        'Taha_Yassin_Ramadan ', 'David_Nalbandian ', 'John_Kerry ',
#        'Halle_Berry ', 'Meryl_Streep ', 'Joschka_Fischer ',
#        'Pervez_Musharraf ', 'Bill_Gates ', 'Nicole_Kidman ',
#        'Amelie_Mauresmo ', 'Jennifer_Aniston ', 'Roh_Moo',
#        'Mahmoud_Abbas ', 'Bill_Clinton ', 'Gloria_Macapagal_Arroyo '],
#       dtype=object)

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# %cd Face\ Dataset
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset

# %%
# !ls
# Out:
# '1-Gathering Face Data.ipynb'	     Augmented_Images   name.npy
# '2-Data Pre-Processing.ipynb'	     final_face_data    shortened_image_set.npy
# '3-Data Augmentation.ipynb'	     image_path.npy     shortened_name_set.npy
# '4-Final Data Preprocessing.ipynb'   lfw	        Untitled0.ipynb

# %%
# %cd Augmented_Images/
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images

# %%
# !ls
# Out:
# fs_height_rotation_horizontal  fs_zoom_horizontal     zca_width_horizontal
# fs_shear_horizontal	       zca_height_horizontal  zca_with_rotation
# fs_width_rotation_horizontal   zca_shear_horizontal

# %%
path1 = os.path.join(os.getcwd(), 'fs_height_rotation_horizontal')
path2 = os.path.join(os.getcwd(), 'fs_shear_horizontal')
path3 = os.path.join(os.getcwd(), 'fs_width_rotation_horizontal')
path4 = os.path.join(os.getcwd(), 'fs_zoom_horizontal')
path5 = os.path.join(os.getcwd(), 'zca_height_horizontal')
path6 = os.path.join(os.getcwd(), 'zca_shear_horizontal')
path7 = os.path.join(os.getcwd(), 'zca_width_horizontal')
path8 = os.path.join(os.getcwd(), 'zca_with_rotation')

# %%
images = []
for i in os.listdir(path1):
  images.append(os.path.join(path1, i))
for i in os.listdir(path2):
  images.append(os.path.join(path2, i))
for i in os.listdir(path3):
  images.append(os.path.join(path3, i))
for i in os.listdir(path4):
  images.append(os.path.join(path4, i))
for i in os.listdir(path5):
  images.append(os.path.join(path5, i))
for i in os.listdir(path6):
  images.append(os.path.join(path6, i))
for i in os.listdir(path7):
  images.append(os.path.join(path7, i))
for i in os.listdir(path8):
  images.append(os.path.join(path8, i))

# %%
len(images)
# Out:
# 8200

# %%
columns = ['images']
pending_df = pd.DataFrame(columns = columns)
pending_df['images'] = images
pending_df.head()
# Out:
#                                                                                                                           images
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg

# %%
pending_df['image_name'] = pending_df['images'].str.split('/').str[-1]
pending_df.head()
# Out:
#                                                                                                                           images                  image_name
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  Tung_Chee-hwa - _0_886.jpg
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  Vaclav_Havel - _0_9346.jpg
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  Vaclav_Havel - _0_3334.jpg
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  Vaclav_Havel - _0_1328.jpg
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    Paul_ONeill - _0_954.jpg

# %%
pending_df['label'] = pending_df['image_name'].str.split('-').str[0]
pending_df.head()
# Out:
#                                                                                                                           images  ...          label
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  Tung_Chee
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  Vaclav_Havel
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  Vaclav_Havel
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  Vaclav_Havel
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  Paul_ONeill
#
# [5 rows x 3 columns]

# %%
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present
pending_df.head()
# Out:
#                                                                                                                           images  ... present
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  no
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  no
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  no
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  no
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  no
#
# [5 rows x 4 columns]

# %%
pending_testing_df = pending_df.loc[pending_df['present'] == 'yes']

# %%
pending_testing_df = pending_testing_df.sort_values('label', ascending = False).groupby('label').head(1)

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images

# %%
testing_path
# Out:
# '/content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set'

# %%
pending_testing_df = pending_testing_df.reset_index(drop = True)
new_path = []
for i in range(len(pending_testing_df)):
  path = os.path.join(testing_path, pending_testing_df['image_name'][i])
  new_path.append(path)
pending_testing_df['new_path'] = new_path
pending_testing_df.head()
# Out:
#                                                                                                                            images  ...                                                                                                 new_path
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_width_rotation_horizontal/Wen_Jiabao - _0_6251.jpg      ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/Wen_Jiabao - _0_6251.jpg
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_width_horizontal/Tom_Hanks - _0_9129.jpg               ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/Tom_Hanks - _0_9129.jpg
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Thomas_OBrien - _0_3816.jpg  ...  /content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/Thomas_OBrien - _0_3816.jpg
# ...

# %%
for i in range(len(pending_testing_df)):
  shutil.move(pending_testing_df['images'][i], pending_testing_df['new_path'][i])

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images

# %%
len(os.listdir(testing_path))
# Out:
# 10369

# %%
len(testing_df)
# Out:
# 10370

# %%
images = []
for i in os.listdir(testing_path):
  images.append(i)
testing_df_2 = pd.DataFrame(columns = ['images'])
testing_df_2['images'] = images
testing_df_2.head()
# Out:
#                          images
# 0  Vaclav_Havel - _0_2174.jpg
# 1  Vaclav_Havel - _0_2744.jpg
# 2  George_Clooney - _0_7911.jpg
# 3  Paul_ONeill - _0_286.jpg
# 4  Paul_ONeill - _0_1622.jpg

# %%
testing_df_2['label'] = testing_df_2['images'].str.split('-').str[0]
testing_df_2.head()
# Out:
#                          images            label
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel
# 2  George_Clooney - _0_7911.jpg  George_Clooney
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill
# 4  Paul_ONeill - _0_1622.jpg     Paul_ONeill

# %%
testing_df_2['label_count'] = testing_df_2['label'].map(testing_df_2['label'].value_counts(dropna = False))
testing_df_2.head()
# Out:
#                          images            label  label_count
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel     61
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel     61
# 2  George_Clooney - _0_7911.jpg  George_Clooney   61
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill      61
# 4  Paul_ONeill - _0_1622.jpg     Paul_ONeill      61

# %%
label = testing_df_2.loc[testing_df_2['label_count']<61]['label'].unique()

# %%
pending_df.head()
# Out:
#                                                                                                                           images  ... present
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  no
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  no
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  no
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  no
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  no
#
# [5 rows x 4 columns]

# %%
label
# Out:
# array(['Meryl_Streep '], dtype=object)

# %%
pending_df.loc[pending_df['label'].str.contains('Mer')].head(1)
# Out:
#                                                                                                                             images  ... present
# 559  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Meryl_Streep - _0_5095.jpg  ...  yes
#
# [1 rows x 4 columns]

# %%
shutil.move('/content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Meryl_Streep - _0_5095.jpg', os.path.join(testing_path, 'Meryl_Streep - _0_5095.jpg'))
# Out:
# '/content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/Meryl_Streep - _0_5095.jpg'

# %%
len(os.listdir(testing_path))
# Out:
# 10370

# %% [markdown]
# # Making up for training set

# %%
len(training_df)
# Out:
# 42500

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Face Dataset

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       'Data Augmentation'
# '2-Gathering files information.ipynb'  'Face Dataset'
# '3-Data Pre-Processing.ipynb'	        Final_Face_Dataset
# '4-Gathering Raw Waveforms.ipynb'       mel_spectrograms
# '5-Concatenating Raw Waveforms.ipynb'   raw_data

# %%
# %cd Final_Face_Dataset/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd training_set/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %%
training_path = os.getcwd()

# %%
len(os.listdir(training_path))
# Out:
# 42068

# %%
images = []
for i in os.listdir(training_path):
  images.append(i)
training_df_2 = pd.DataFrame(columns = ['images'])
training_df_2['images'] = images
training_df_2.head()
# Out:
#                         images
# 0  Tung_Chee-hwa - _0_8293.jpg
# 1  Tung_Chee-hwa - _0_1601.jpg
# 2  Vaclav_Havel - _0_1306.jpg
# 3  Vaclav_Havel - _0_3141.jpg
# 4  Vaclav_Havel - _0_4436.jpg

# %%
training_df_2['label'] = training_df_2['images'].str.split('-').str[0]
training_df_2.head()
# Out:
#                         images          label
# 0  Tung_Chee-hwa - _0_8293.jpg  Tung_Chee
# 1  Tung_Chee-hwa - _0_1601.jpg  Tung_Chee
# 2  Vaclav_Havel - _0_1306.jpg   Vaclav_Havel
# 3  Vaclav_Havel - _0_3141.jpg   Vaclav_Havel
# 4  Vaclav_Havel - _0_4436.jpg   Vaclav_Havel

# %%
training_df_2['label_count'] = training_df_2['label'].map(training_df_2['label'].value_counts(dropna = False))
training_df_2.head()
# Out:
#                         images          label  label_count
# 0  Tung_Chee-hwa - _0_8293.jpg  Tung_Chee      249
# 1  Tung_Chee-hwa - _0_1601.jpg  Tung_Chee      249
# 2  Vaclav_Havel - _0_1306.jpg   Vaclav_Havel   248
# 3  Vaclav_Havel - _0_3141.jpg   Vaclav_Havel   248
# 4  Vaclav_Havel - _0_4436.jpg   Vaclav_Havel   248

# %%
training_df_2.loc[training_df_2['label_count'] < 250]['label_count'].unique()
# Out:
# array([249, 248, 247, 246, 243, 245, 244, 242])

# %%
missing_1 = training_df_2.loc[training_df_2['label_count'] == 249]
missing_2 = training_df_2.loc[training_df_2['label_count'] == 248]
missing_3 = training_df_2.loc[training_df_2['label_count'] == 247]
missing_4 = training_df_2.loc[training_df_2['label_count'] == 246]
missing_5 = training_df_2.loc[training_df_2['label_count'] == 245]
missing_6 = training_df_2.loc[training_df_2['label_count'] == 244]
missing_7 = training_df_2.loc[training_df_2['label_count'] == 243]
missing_8 = training_df_2.loc[training_df_2['label_count'] == 242]

# %%
missing_1.head()
# Out:
#                            images            label  label_count
# 0    Tung_Chee-hwa - _0_8293.jpg   Tung_Chee        249
# 1    Tung_Chee-hwa - _0_1601.jpg   Tung_Chee        249
# 104  Charles_Taylor - _0_5870.jpg  Charles_Taylor   249
# 105  Charles_Taylor - _0_8888.jpg  Charles_Taylor   249
# 106  Charles_Taylor - _0_8821.jpg  Charles_Taylor   249

# %%
missing_1_label = missing_1['label'].unique()

# %%
pending_df.head()
# Out:
#                                                                                                                           images  ... present
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  no
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  no
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  no
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  no
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  no
#
# [5 rows x 4 columns]

# %%
del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_1_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present
pending_df.head()
# Out:
#                                                                                                                           images  ... present
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  yes
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  no
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  no
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  no
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  no
#
# [5 rows x 4 columns]

# %%
missing_pending_1 = pending_df.loc[pending_df['present'] == 'yes']
missing_pending_1.head()
# Out:
#                                                                                                                              images  ... present
# 0   /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg    ...  yes
# 23  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Charles_Taylor - _0_5038.jpg  ...  yes
# 24  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Charles_Taylor - _0_7371.jpg  ...  yes
# 28  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/John_Abizaid - _0_9903.jpg    ...  yes
# 29  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/John_Abizaid - _0_1562.jpg    ...  yes
#
# [5 rows x 4 columns]

# %%
missing_pending_1 = missing_pending_1.sort_values('label', ascending = False).groupby('label').tail(1)
missing_pending_1 = missing_pending_1.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_1)):
  path = os.path.join(testing_path, missing_pending_1['image_name'][i])
  new_path.append(path)
missing_pending_1['new_path'] = new_path

for i in range(len(missing_pending_1)):
  shutil.move(missing_pending_1['images'][i], missing_pending_1['new_path'][i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.6/shutil.py in move(src, dst, copy_function)
#     549     try:
# --> 550         os.rename(src, real_dst)
#     551     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_height_horizontal/Wen_Jiabao - _0_205.jpg' -> '/content/drive/My Drive/case studies 2/Final_Face_Dataset/testing_set/Wen_Jiabao - _0_205.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-245-a1b64ffca7c5> in <module>()
#       8
#       9 for i in range(len(missing_pending_1)):
# ---> 10   shutil.move(missing_pending_1['images'][i], missing_pending_1['new_path'][i])
#
# ...

# %%
missing_2.head()
# Out:
#                          images            label  label_count
# 2  Vaclav_Havel - _0_1306.jpg    Vaclav_Havel     248
# 3  Vaclav_Havel - _0_3141.jpg    Vaclav_Havel     248
# 4  Vaclav_Havel - _0_4436.jpg    Vaclav_Havel     248
# 8  George_Clooney - _0_8420.jpg  George_Clooney   248
# 9  George_Clooney - _0_8848.jpg  George_Clooney   248

# %%
missing_2_label = missing_2['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_2_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_2 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_2 = missing_pending_2.sort_values('label', ascending = False).groupby('label').tail(2)
missing_pending_2 = missing_pending_2.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_2)):
  path = os.path.join(testing_path, missing_pending_2['image_name'][i])
  new_path.append(path)
missing_pending_2['new_path'] = new_path

for i in range(len(missing_pending_2)):
  shutil.move(missing_pending_2['images'][i], missing_pending_2['new_path'][i])

# %%
missing_3.head()
# Out:
#                          images           label  label_count
# 5   Li_Peng - _0_967.jpg         Li_Peng         247
# 6   Li_Peng - _0_8731.jpg        Li_Peng         247
# 7   Li_Peng - _0_1742.jpg        Li_Peng         247
# 63  Colin_Farrell - _0_3059.jpg  Colin_Farrell   247
# 64  Colin_Farrell - _0_2063.jpg  Colin_Farrell   247

# %%
missing_3_label = missing_3['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_3_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_3 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_3 = missing_pending_3.sort_values('label', ascending = False).groupby('label').tail(3)
missing_pending_3 = missing_pending_3.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_3)):
  path = os.path.join(testing_path, missing_pending_3['image_name'][i])
  new_path.append(path)
missing_pending_3['new_path'] = new_path

for i in range(len(missing_pending_3)):
  try:
    shutil.move(missing_pending_3['images'][i], missing_pending_3['new_path'][i])
  except Exception as e:
    pass

# %%
missing_4.head()
# Out:
#                        images         label  label_count
# 30  Paul_ONeill - _0_6075.jpg  Paul_ONeill   246
# 31  Paul_ONeill - _0_282.jpg   Paul_ONeill   246
# 32  Paul_ONeill - _0_2940.jpg  Paul_ONeill   246
# 33  Paul_ONeill - _0_2273.jpg  Paul_ONeill   246
# 34  Paul_ONeill - _0_3352.jpg  Paul_ONeill   246

# %%
missing_4_label = missing_4['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_4_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_4 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_4 = missing_pending_4.sort_values('label', ascending = False).groupby('label').tail(4)
missing_pending_4 = missing_pending_4.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_4)):
  path = os.path.join(testing_path, missing_pending_4['image_name'][i])
  new_path.append(path)
missing_pending_4['new_path'] = new_path

for i in range(len(missing_pending_4)):
  try:
    shutil.move(missing_pending_4['images'][i], missing_pending_4['new_path'][i])
  except Exception as e:
    pass

# %%
missing_5.head()
# Out:
#                        images        label  label_count
# 840  Jason_Kidd - _0_6917.jpg  Jason_Kidd   245
# 841  Jason_Kidd - _0_7475.jpg  Jason_Kidd   245
# 842  Jason_Kidd - _0_3042.jpg  Jason_Kidd   245
# 843  Jason_Kidd - _0_6746.jpg  Jason_Kidd   245
# 844  Jason_Kidd - _0_4524.jpg  Jason_Kidd   245

# %%
missing_5_label = missing_5['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_5_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_5 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_5 = missing_pending_5.sort_values('label', ascending = False).groupby('label').tail(5)
missing_pending_5 = missing_pending_5.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_5)):
  path = os.path.join(testing_path, missing_pending_5['image_name'][i])
  new_path.append(path)
missing_pending_5['new_path'] = new_path

for i in range(len(missing_pending_5)):
  try:
    shutil.move(missing_pending_5['images'][i], missing_pending_5['new_path'][i])
  except Exception as e:
    pass

# %%
missing_6.head()
# Out:
#                          images         label  label_count
# 3263  Carlos_Moya - _0_5234.jpg  Carlos_Moya   244
# 3264  Carlos_Moya - _0_5456.jpg  Carlos_Moya   244
# 3265  Carlos_Moya - _0_9268.jpg  Carlos_Moya   244
# 3266  Carlos_Moya - _0_313.jpg   Carlos_Moya   244
# 3267  Carlos_Moya - _0_1213.jpg  Carlos_Moya   244

# %%
missing_6_label = missing_6['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_6_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_6 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_6 = missing_pending_6.sort_values('label', ascending = False).groupby('label').tail(6)
missing_pending_6 = missing_pending_6.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_6)):
  path = os.path.join(testing_path, missing_pending_6['image_name'][i])
  new_path.append(path)
missing_pending_6['new_path'] = new_path

for i in range(len(missing_pending_6)):
  try:
    shutil.move(missing_pending_6['images'][i], missing_pending_6['new_path'][i])
  except Exception as e:
    pass

# %%
missing_7.head()
# Out:
#                            images            label  label_count
# 302  Tommy_Thompson - _0_5314.jpg  Tommy_Thompson   243
# 303  Tommy_Thompson - _0_2691.jpg  Tommy_Thompson   243
# 304  Tommy_Thompson - _0_5737.jpg  Tommy_Thompson   243
# 305  Tommy_Thompson - _0_5074.jpg  Tommy_Thompson   243
# 306  Tommy_Thompson - _0_9491.jpg  Tommy_Thompson   243

# %%
missing_7_label = missing_7['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_7_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_7 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_7 = missing_pending_7.sort_values('label', ascending = False).groupby('label').tail(7)
missing_pending_7 = missing_pending_7.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_7)):
  path = os.path.join(testing_path, missing_pending_7['image_name'][i])
  new_path.append(path)
missing_pending_7['new_path'] = new_path

for i in range(len(missing_pending_7)):
  try:
    shutil.move(missing_pending_7['images'][i], missing_pending_7['new_path'][i])
  except Exception as e:
    pass

# %%
missing_8.head()
# Out:
#                          images         label  label_count
# 3432  Tiger_Woods - _0_4714.jpg  Tiger_Woods   242
# 3433  Tiger_Woods - _0_3506.jpg  Tiger_Woods   242
# 3434  Tiger_Woods - _0_262.jpg   Tiger_Woods   242
# 3435  Tiger_Woods - _0_8187.jpg  Tiger_Woods   242
# 3436  Tiger_Woods - _0_4684.jpg  Tiger_Woods   242

# %%
missing_8_label = missing_8['label'].unique()

del pending_df['present']
present = []
for i in range(len(pending_df)):
  if pending_df['label'][i] in missing_8_label:
    present.append('yes')
  else:
    present.append('no')
pending_df['present'] = present

missing_pending_8 = pending_df.loc[pending_df['present'] == 'yes']

missing_pending_8 = missing_pending_8.sort_values('label', ascending = False).groupby('label').tail(8)
missing_pending_8 = missing_pending_8.reset_index(drop = True)
new_path = []
for i in range(len(missing_pending_8)):
  path = os.path.join(testing_path, missing_pending_8['image_name'][i])
  new_path.append(path)
missing_pending_8['new_path'] = new_path

for i in range(len(missing_pending_8)):
  try:
    shutil.move(missing_pending_8['images'][i], missing_pending_8['new_path'][i])
  except Exception as e:
    pass

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd training_set/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %%
len(os.listdir(os.getcwd()))
# Out:
# 42068

# %%
len(os.listdir(training_path))
# Out:
# 42068

# %%
len(os.listdir(testing_path))
# Out:
# 11201

# %%
images = []
for i in os.listdir(testing_path):
  images.append(i)
test = pd.DataFrame(columns = ['images'])
test['images'] = images
test['labels'] = test['images'].str.split('-').str[0]
test['label_count'] = test['labels'].map(test['labels'].value_counts(dropna = False))
test.head()
# Out:
#                          images           labels  label_count
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel     65
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel     65
# 2  George_Clooney - _0_7911.jpg  George_Clooney   65
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill      69
# 4  Paul_ONeill - _0_9667.jpg     Paul_ONeill      69

# %%
test.loc[test['label_count'] > 61]['label_count'].unique()
# Out:
# array([65, 69, 67, 62, 75, 71, 68, 66, 73, 77])

# %%
final_test = test.sort_values('labels', ascending = False).groupby('labels').head(61)

# %%
images = []
final_test = final_test.reset_index(drop = True)
for i in range(len(final_test)):
  images.append(final_test['images'][i])

# %%
present = []
for i in test['images']:
  if i in images:
    present.append('yes')
  else:
    present.append('no')
test['present'] = present
test.head()
# Out:
#                          images           labels  label_count present
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel     65           yes
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel     65           yes
# 2  George_Clooney - _0_7911.jpg  George_Clooney   65           yes
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill      69           yes
# 4  Paul_ONeill - _0_9667.jpg     Paul_ONeill      69           yes

# %%
train = test.loc[test['present'] == 'no']

# %%
train
# Out:
#                             images          labels  label_count present
# 16     Colin_Farrell - _0_4834.jpg  Colin_Farrell   67           no
# 17     Colin_Farrell - _0_8369.jpg  Colin_Farrell   67           no
# 20     Vaclav_Havel - _0_5054.jpg   Vaclav_Havel    65           no
# 24     Vaclav_Havel - _0_2494.jpg   Vaclav_Havel    65           no
# 25     Vaclav_Havel - _0_7753.jpg   Vaclav_Havel    65           no
# ...                           ...             ...   ..           ..
# 11163  Tony_Blair - _0_3520.jpg     Tony_Blair      71           no
# 11164  Tony_Blair - _0_6241.jpg     Tony_Blair      71           no
# 11165  Tony_Blair - _0_9799.jpg     Tony_Blair      71           no
# 11167  Tony_Blair - _0_5526.jpg     Tony_Blair      71           no
# 11168  Tony_Blair - _0_405.jpg      Tony_Blair      71           no
#
# [831 rows x 4 columns]

# %%
train = train.reset_index(drop = True)

# %%
current_path = []
for i in train['images']:
  path = os.path.join(testing_path, i)
  current_path.append(path)
train['current_path'] = current_path

to_path = []
for i in train['images']:
  path = os.path.join(training_path, i)
  to_path.append(path)
train['to_path'] = to_path

for i in range(len(train)):
  try:
    shutil.move(train['current_path'][i], train['to_path'][i])
  except Exception as e:
    pass

# %%
len(os.listdir(testing_path))
# Out:
# 10370

# %%
len(os.listdir(training_path))
# Out:
# 42883

# %%
len(training_df)
# Out:
# 42500

# %%
images = []
for i in os.listdir(training_path):
  images.append(i)
train = pd.DataFrame(columns = ['images'])
train['images'] = images
train['labels'] = train['images'].str.split('-').str[0]
train['label_count'] = train['labels'].map(train['labels'].value_counts(dropna = False))
train.head()
# Out:
#                         images         labels  label_count
# 0  Tung_Chee-hwa - _0_8293.jpg  Tung_Chee      249
# 1  Tung_Chee-hwa - _0_1601.jpg  Tung_Chee      249
# 2  Vaclav_Havel - _0_1306.jpg   Vaclav_Havel   252
# 3  Vaclav_Havel - _0_3141.jpg   Vaclav_Havel   252
# 4  Vaclav_Havel - _0_4436.jpg   Vaclav_Havel   252

# %%
train.loc[train['label_count']<250]['labels'].unique()
# Out:
# array(['Tung_Chee', 'George_Robertson '], dtype=object)

# %%
pending_df.head()
# Out:
#                                                                                                                           images  ... present
# 0  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Tung_Chee-hwa - _0_886.jpg  ...  no
# 1  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_9346.jpg  ...  yes
# 2  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_3334.jpg  ...  yes
# 3  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Vaclav_Havel - _0_1328.jpg  ...  yes
# 4  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/fs_height_rotation_horizontal/Paul_ONeill - _0_954.jpg    ...  no
#
# [5 rows x 4 columns]

# %%
pending_df.loc[pending_df['label'].str.contains('Tung')].tail(5)
# Out:
#                                                                                                                   images  ... present
# 7247  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_8584.jpg  ...  no
# 7248  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_2686.jpg  ...  no
# 7307  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_9612.jpg  ...  no
# 7309  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_3823.jpg  ...  no
# 7316  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_3389.jpg  ...  no
#
# [5 rows x 4 columns]

# %%
shutil.move('/content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/Tung_Chee-hwa - _0_9612.jpg', os.path.join(training_path, 'Tung_Chee-hwa - _0_9612.jpg'))
# Out:
# '/content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/Tung_Chee-hwa - _0_9612.jpg'

# %%
pending_df.loc[pending_df['label'].str.contains('Robertson')].tail(5)
# Out:
#                                                                                                                      images  ... present
# 7877  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_6322.jpg  ...  no
# 7878  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_9819.jpg  ...  no
# 7879  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_9253.jpg  ...  no
# 7880  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_6043.jpg  ...  no
# 7881  /content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_391.jpg   ...  no
#
# [5 rows x 4 columns]

# %%
shutil.move('/content/drive/My Drive/case studies 2/Face Dataset/Augmented_Images/zca_with_rotation/George_Robertson - _0_6043.jpg', os.path.join(training_path, 'George_Robertson - _0_6043.jpg'))
# Out:
# '/content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set/George_Robertson - _0_6043.jpg'

# %%
images = []
for i in os.listdir(training_path):
  images.append(i)
train = pd.DataFrame(columns = ['images'])
train['images'] = images
train['labels'] = train['images'].str.split('-').str[0]
train['label_count'] = train['labels'].map(train['labels'].value_counts(dropna = False))
train.head()
# Out:
#                         images         labels  label_count
# 0  Tung_Chee-hwa - _0_8293.jpg  Tung_Chee      250
# 1  Tung_Chee-hwa - _0_1601.jpg  Tung_Chee      250
# 2  Vaclav_Havel - _0_1306.jpg   Vaclav_Havel   252
# 3  Vaclav_Havel - _0_3141.jpg   Vaclav_Havel   252
# 4  Vaclav_Havel - _0_4436.jpg   Vaclav_Havel   252

# %%
train.loc[train['label_count'] > 250]
# Out:
#                                   images                labels  label_count
# 2      Vaclav_Havel - _0_1306.jpg         Vaclav_Havel          252
# 3      Vaclav_Havel - _0_3141.jpg         Vaclav_Havel          252
# 4      Vaclav_Havel - _0_4436.jpg         Vaclav_Havel          252
# 5      Li_Peng - _0_967.jpg               Li_Peng               253
# 6      Li_Peng - _0_8731.jpg              Li_Peng               253
# ...                      ...                   ...              ...
# 42849  Gerhard_Schroeder - _0_9165.jpg    Gerhard_Schroeder     253
# 42850  Gerhard_Schroeder - _0_652.jpg     Gerhard_Schroeder     253
# 42851  Gerhard_Schroeder - _0_2025.jpg    Gerhard_Schroeder     253
# 42852  Gerhard_Schroeder - _0_9639.jpg    Gerhard_Schroeder     253
# 42884  Juan_Carlos_Ferrero - _0_6987.jpg  Juan_Carlos_Ferrero   254
#
# [31385 rows x 3 columns]

# %%
final_training_data = train.sort_values('labels', ascending = False).groupby('labels').head(250)

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/training_set

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
final_training_data.to_csv('final_training_data.csv')

# %%
images = [i for i in os.listdir(testing_path)]
df = pd.DataFrame(columns = ['images'])
df['images'] = images
df['labels'] = df['images'].str.split('-').str[0]
df.head()
# Out:
#                          images           labels
# 0  Vaclav_Havel - _0_2174.jpg    Vaclav_Havel
# 1  Vaclav_Havel - _0_2744.jpg    Vaclav_Havel
# 2  George_Clooney - _0_7911.jpg  George_Clooney
# 3  Paul_ONeill - _0_286.jpg      Paul_ONeill
# 4  Paul_ONeill - _0_9667.jpg     Paul_ONeill

# %%
len(df)
# Out:
# 10370

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
df.to_csv('final_test_data.csv')
