# %% [markdown]
# **Below are the steps taken to create the final training, testing and unseen faces data**

# %% [markdown]
# # Setting up the path and some experimentation

# %%
import os
import shutil
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd /content/drive/My Drive/case studies 2/Final_Face_Dataset/MTCNN experiments/concatenated_training
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/MTCNN experiments/concatenated_training

# %%
# !ls
# Out:
# cleaned_images.csv  cropped_images.npy		 delete_faces_1.py
# cleaned_images.npy  cropped_training_images.csv  delete_faces_2.py

# %%
df_1 = pd.read_csv('cleaned_images.csv')
np_1 = np.load('cleaned_images.npy', allow_pickle=True)
print(len(df_1))
print(len(np_1))
# Out:
# 43982
# 43982

# %%
df_1.head()
# Out:
#    Unnamed: 0              label                           image  faces_found
# 0           0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg            1
# 1           1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg            1
# 2           2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg            1
# 3           3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg            1
# 4           4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg            1

# %%
sf_df_1 = df_1.loc[df_1['faces_found'] == 1]
print(len(sf_df_1))
# Out:
# 41068

# %%
sf_df_1.head()
# Out:
#    Unnamed: 0              label                           image  faces_found
# 0           0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg            1
# 1           1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg            1
# 2           2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg            1
# 3           3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg            1
# 4           4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg            1

# %%
sf_df_1.tail()
# Out:
#        Unnamed: 0          label                       image  faces_found
# 43953       43953  Abdullah_Gul   Abdullah_Gul - _0_6482.jpg            1
# 43954       43954  Abdullah_Gul   Abdullah_Gul - _0_6512.jpg            1
# 43955       43955  Abdullah_Gul   Abdullah_Gul - _0_8248.jpg            1
# 43958       43958  Abdullah_Gul   Abdullah_Gul - _0_9438.jpg            1
# 43971       43971  Abdullah_Gul   Abdullah_Gul - _0_3009.jpg            1

# %%
index = list(sf_df_1.index)
len(index)
# Out:
# 41068

# %%
sf_np_1 = np_1[index]
len(sf_np_1)
# Out:
# 41068

# %%
sf_df_1 = sf_df_1.reset_index(drop = True)
sf_df_1.tail()
# Out:
#        Unnamed: 0          label                       image  faces_found
# 41063       43953  Abdullah_Gul   Abdullah_Gul - _0_6482.jpg            1
# 41064       43954  Abdullah_Gul   Abdullah_Gul - _0_6512.jpg            1
# 41065       43955  Abdullah_Gul   Abdullah_Gul - _0_8248.jpg            1
# 41066       43958  Abdullah_Gul   Abdullah_Gul - _0_9438.jpg            1
# 41067       43971  Abdullah_Gul   Abdullah_Gul - _0_3009.jpg            1

# %%
plt.imshow(sf_np_1[41063])

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/MTCNN experiments

# %%
# !ls
# Out:
#  0_10000_training	   concatenated_training
#  10000_20000_training	  'Cropped Images Data Concatenation.ipynb'
#  20000_30000_training	  'Face Detection Using MTCNN.ipynb'
#  30000_40000_training	   testing
# 'Cleaning Documentation'   Untitled0.ipynb
#  concatenated_testing

# %%
# %cd concatenated_testing/
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/MTCNN experiments/concatenated_testing

# %%
# !ls
# Out:
# cropped_images.npy  cropped_testing_images.csv

# %%
df_2 = pd.read_csv('cropped_testing_images.csv')
np_2 = np.load('cropped_images.npy', allow_pickle=True)
print(len(df_2))
print(len(np_2))
# Out:
# 11806
# 11806

# %%
df_2.head()
# Out:
#    Unnamed: 0            label                         image  faces_found
# 0           0    Vaclav_Havel     Vaclav_Havel - _0_2174.jpg            1
# 1           1    Vaclav_Havel     Vaclav_Havel - _0_2744.jpg            1
# 2           2  George_Clooney   George_Clooney - _0_7911.jpg            2
# 3           3  George_Clooney   George_Clooney - _0_7911.jpg            2
# 4           4     Paul_ONeill       Paul_ONeill - _0_286.jpg            1

# %%
sf_df_2 = df_2.loc[df_2['faces_found'] == 1]
len(sf_df_2)
# Out:
# 9111

# %%
sf_df_2.head()
# Out:
#    Unnamed: 0          label                       image  faces_found
# 0           0  Vaclav_Havel   Vaclav_Havel - _0_2174.jpg            1
# 1           1  Vaclav_Havel   Vaclav_Havel - _0_2744.jpg            1
# 4           4   Paul_ONeill     Paul_ONeill - _0_286.jpg            1
# 5           5   Paul_ONeill    Paul_ONeill - _0_9667.jpg            1
# 6           6   Paul_ONeill    Paul_ONeill - _0_1622.jpg            1

# %%
index_2 = list(sf_df_2.index)
len(index_2)
# Out:
# 9111

# %%
sf_np_2 = np_2[index_2]
len(sf_np_2)
# Out:
# 9111

# %%
sf_df_2 = sf_df_2.reset_index(drop = True)
sf_df_2.tail()
# Out:
#       Unnamed: 0          label                       image  faces_found
# 9106       11799  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg            1
# 9107       11800  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg            1
# 9108       11801  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg            1
# 9109       11802  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg            1
# 9110       11805   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg            1

# %%
plt.imshow(sf_np_2[9110])

# %%
plt.imshow(sf_np_2[9109])

# %%
plt.imshow(sf_np_2[9108])

# %%
combined_np = []
for i in sf_np_1:
  combined_np.append(i)
for i in sf_np_2:
  combined_np.append(i)
print(len(combined_np))
# Out:
# 50179

# %%
plt.imshow(combined_np[-1])

# %%
sf_df_1.head()
# Out:
#    Unnamed: 0              label                           image  faces_found
# 0           0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg            1
# 1           1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg            1
# 2           2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg            1
# 3           3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg            1
# 4           4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg            1

# %%
sf_df_2.head()
# Out:
#    Unnamed: 0          label                       image  faces_found
# 0           0  Vaclav_Havel   Vaclav_Havel - _0_2174.jpg            1
# 1           1  Vaclav_Havel   Vaclav_Havel - _0_2744.jpg            1
# 2           4   Paul_ONeill     Paul_ONeill - _0_286.jpg            1
# 3           5   Paul_ONeill    Paul_ONeill - _0_9667.jpg            1
# 4           6   Paul_ONeill    Paul_ONeill - _0_1622.jpg            1

# %%
label = []
image = []

for i in sf_df_1['label']:
  label.append(i)
for i in sf_df_2['label']:
  label.append(i)
for i in sf_df_1['image']:
  image.append(i)
for i in sf_df_2['image']:
  image.append(i)
print(len(label))
print(len(image))
# Out:
# 50179
# 50179

# %%
combined_df = pd.DataFrame(columns = ['label', 'image'])
combined_df['label'] = label
combined_df['image'] = image
combined_df.head()
# Out:
#                label                           image
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg

# %%
len(combined_df)
# Out:
# 50179

# %%
plt.imshow(combined_np[0])

# %%
combined_df.tail()
# Out:
#                label                       image
# 50174  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg
# 50175  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg
# 50176  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg
# 50177  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg
# 50178   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg

# %%
plt.imshow(combined_np[50177])

# %%
plt.imshow(combined_np[50176])

# %%
combined_df.head()
# Out:
#                label                           image
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg

# %%
combined_df['label_count'] = combined_df['label'].map(combined_df['label'].value_counts(dropna = False))
combined_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
combined_df.loc[combined_df['label_count']>=250]['label'].nunique()
# Out:
# 163

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset/MTCNN experiments

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Face_Dataset

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       'Data Augmentation'
# '2-Gathering files information.ipynb'  'Face Dataset'
# '3-Data Pre-Processing.ipynb'	        Final_Face_Dataset
# '4-Gathering Raw Waveforms.ipynb'       mel_spectrograms
# '5-Concatenating Raw Waveforms.ipynb'   raw_data

# %%
os.mkdir('Final Data')

# %%
os.rmdir('Final Data')

# %%
os.mkdir('Final_Data')

# %%
# %cd Final_Data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data

# %%
os.mkdir('Final_Face_Data')

# %%
# %cd Final_Face_Data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
combined_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
combined_df.to_csv('combined_data.csv')

# %%
len(combined_df)
# Out:
# 50179

# %%
len(combined_np)
# Out:
# 50179

# %%
combined_df.tail()
# Out:
#                label                       image  label_count
# 50174  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg          270
# 50175  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg          270
# 50176  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg          270
# 50177  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg          270
# 50178   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg          296

# %%
np.save('combined_data', combined_np, allow_pickle=True)

# %%
# !ls
# Out:
# combined_data.csv  combined_data.npy

# %%
combined_df.loc[combined_df['label_count']>260]['label'].nunique()
# Out:
# 160

# %%
# !ls
# Out:
# combined_data.csv  combined_data.npy

# %%
for i in os.listdir(os.getcwd()):
  os.remove(i)

# %%
# !ls

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
os.mkdir('single_faces_data')

# %%
# %cd single_faces_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/single_faces_data

# %%
combined_df.to_csv('combined_data.csv')
np.save('combined_data', combined_np, allow_pickle=True)

# %%
# !ls
# Out:
# combined_data.csv  combined_data.npy

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
os.mkdir('training_data')

# %%
os.mkdir('test_data')

# %% [markdown]
# # Random tests

# %%
train_df = combined_df.loc[combined_df['label_count']>260]

# %%
train_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
train_df['label'].nunique()
# Out:
# 160

# %%
train_df.sort_values('label', ascending = False).groupby('label').head(200)
# Out:
#                    label                           image  label_count
# 0      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 201    Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 209    Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 208    Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 206    Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304
# ...                  ...                             ...          ...
# 40705  Alejandro_Toledo   Alejandro_Toledo - _0_3915.jpg          303
# 40704  Alejandro_Toledo   Alejandro_Toledo - _0_2414.jpg          303
# 40703  Alejandro_Toledo    Alejandro_Toledo - _0_514.jpg          303
# 40702  Alejandro_Toledo   Alejandro_Toledo - _0_8306.jpg          303
# 40701  Alejandro_Toledo   Alejandro_Toledo - _0_6180.jpg          303
#
# [32000 rows x 3 columns]

# %%
train_df.sort_values('label', ascending = False).groupby('label').head(200)['label'].nunique()
# Out:
# 160

# %%
train_df.sort_values('label', ascending = False).groupby('label').head(200)['label'].value_counts(dropna = False)
# Out:
# Tony_Blair            200
# Richard_Myers         200
# Tom_Ridge             200
# Salma_Hayek           200
# Mahmoud_Abbas         200
#                      ...
# Ari_Fleischer         200
# Thomas_OBrien         200
# Michael_Bloomberg     200
# Jennifer_Aniston      200
# Hugo_Chavez           200
# Name: label, Length: 160, dtype: int64

# %%
final_training_df = train_df.sort_values('label', ascending = False).groupby('label').head(200)

# %%
len(final_training_df)
# Out:
# 32000

# %%
final_training_df.head()
# Out:
#                  label                           image  label_count
# 0    Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 201  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 209  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 208  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 206  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304

# %%
index = list(final_training_df.index)

# %%
len(index)
# Out:
# 32000

# %%
final_training_np = []
for i in index:
  final_training_np.append(combined_np[i])

# %%
len(final_training_np)
# Out:
# 32000

# %%
final_training_df.tail()
# Out:
#                    label                           image  label_count
# 40705  Alejandro_Toledo   Alejandro_Toledo - _0_3915.jpg          303
# 40704  Alejandro_Toledo   Alejandro_Toledo - _0_2414.jpg          303
# 40703  Alejandro_Toledo    Alejandro_Toledo - _0_514.jpg          303
# 40702  Alejandro_Toledo   Alejandro_Toledo - _0_8306.jpg          303
# 40701  Alejandro_Toledo   Alejandro_Toledo - _0_6180.jpg          303

# %%
final_training_df = final_training_df.reset_index(drop = True)
final_training_df.tail()
# Out:
#                    label                           image  label_count
# 31995  Alejandro_Toledo   Alejandro_Toledo - _0_3915.jpg          303
# 31996  Alejandro_Toledo   Alejandro_Toledo - _0_2414.jpg          303
# 31997  Alejandro_Toledo    Alejandro_Toledo - _0_514.jpg          303
# 31998  Alejandro_Toledo   Alejandro_Toledo - _0_8306.jpg          303
# 31999  Alejandro_Toledo   Alejandro_Toledo - _0_6180.jpg          303

# %%
plt.imshow(final_training_np[31999])

# %%
plt.imshow(final_training_np[31998])

# %%
final_training_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 4  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304

# %%
plt.imshow(final_training_np[4])

# %%
# !ls
# Out:
# single_faces_data  test_data  training_data

# %%
# %cd training_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/training_data

# %%
final_training_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 4  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304

# %%
del final_training_df['label_count']

# %%
final_training_df.head()
# Out:
#                label                           image
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg
# 1  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg
# 4  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg

# %%
final_training_df.sample(frac=1)
# Out:
#                      label                             image
# 16502     Joschka_Fischer      Joschka_Fischer - _0_1679.jpg
# 6237               Roh_Moo        Roh_Moo-hyun - _0_8812.jpg
# 31679     Amelie_Mauresmo      Amelie_Mauresmo - _0_1815.jpg
# 1626             Tung_Chee       Tung_Chee-hwa - _0_3255.jpg
# 6278               Roh_Moo        Roh_Moo-hyun - _0_6056.jpg
# ...                    ...                               ...
# 4462      Spencer_Abraham      Spencer_Abraham - _0_7176.jpg
# 7935   Queen_Elizabeth_II   Queen_Elizabeth_II - _0_5080.jpg
# 27228         Dick_Cheney          Dick_Cheney - _0_1915.jpg
# 21468         James_Kelly          James_Kelly - _0_8804.jpg
# 1473         Vaclav_Havel         Vaclav_Havel - _0_3419.jpg
#
# [32000 rows x 2 columns]

# %%
shuffled_training_data = final_training_df.sample(frac = 1)
shuffled_training_data.head()
# Out:
#                     label                            image
# 31227       Andy_Roddick        Andy_Roddick - _0_8525.jpg
# 13483    Lucio_Gutierrez     Lucio_Gutierrez - _0_4856.jpg
# 1589        Vaclav_Havel        Vaclav_Havel - _0_9690.jpg
# 19271  Jeremy_Greenstock   Jeremy_Greenstock - _0_4446.jpg
# 27314        Dick_Cheney         Dick_Cheney - _0_1133.jpg

# %%
len(shuffled_training_data)
# Out:
# 32000

# %%
index = list(shuffled_training_data.index)
len(index)
# Out:
# 32000

# %%
shuffled_training_np = []
for i in index:
  shuffled_training_np.append(final_training_np[i])
len(shuffled_training_np)
# Out:
# 32000

# %%
shuffled_training_data = shuffled_training_data.reset_index(drop = True)
shuffled_training_data.head()
# Out:
#                 label                            image
# 0       Andy_Roddick        Andy_Roddick - _0_8525.jpg
# 1    Lucio_Gutierrez     Lucio_Gutierrez - _0_4856.jpg
# 2       Vaclav_Havel        Vaclav_Havel - _0_9690.jpg
# 3  Jeremy_Greenstock   Jeremy_Greenstock - _0_4446.jpg
# 4        Dick_Cheney         Dick_Cheney - _0_1133.jpg

# %%
plt.imshow(shuffled_training_np[0])

# %%
shuffled_training_data.tail()
# Out:
#                    label                           image
# 31995    Walter_Mondale      Walter_Mondale - _0_807.jpg
# 31996        Tony_Blair         Tony_Blair - _0_2190.jpg
# 31997       James_Kelly        James_Kelly - _0_3179.jpg
# 31998   Serena_Williams    Serena_Williams - _0_5131.jpg
# 31999  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8779.jpg

# %%
plt.imshow(shuffled_training_np[31998])

# %%
shuffled_training_data['label'].value_counts(dropna = False)
# Out:
# Tony_Blair                200
# Paul_Wolfowitz            200
# Dominique_de_Villepin     200
# Tom_Ridge                 200
# Salma_Hayek               200
#                          ...
# Spencer_Abraham           200
# Ari_Fleischer             200
# Thomas_OBrien             200
# Michael_Bloomberg         200
# Hugo_Chavez               200
# Name: label, Length: 160, dtype: int64

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/training_data

# %%
# !ls

# %%
shuffled_training_data.to_csv('training_faces.csv')
np.save('training_faces', shuffled_training_np, allow_pickle=True)

# %%
# !ls
# Out:
# training_faces.csv  training_faces.npy

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
# !ls
# Out:
# single_faces_data  test_data  training_data

# %%
# %cd test_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/test_data

# %%
# !ls

# %%
train_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
train_df['label'].nunique()
# Out:
# 160

# %%
shuffled_training_data.head()
# Out:
#                 label                            image
# 0       Andy_Roddick        Andy_Roddick - _0_8525.jpg
# 1    Lucio_Gutierrez     Lucio_Gutierrez - _0_4856.jpg
# 2       Vaclav_Havel        Vaclav_Havel - _0_9690.jpg
# 3  Jeremy_Greenstock   Jeremy_Greenstock - _0_4446.jpg
# 4        Dick_Cheney         Dick_Cheney - _0_1133.jpg

# %%
training_image = []
for i in shuffled_training_data['image']:
  training_image.append(i)
print(len(training_image))
# Out:
# 32000

# %%
present = []
for i in train_df['image']:
  if i in training_image:
    present.append('yes')
  else:
    present.append('no')
train_df['present'] = present
train_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                label                           image  label_count present
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304     yes
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304     yes
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304      no
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304      no
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304      no

# %%
train_df.loc[train_df['present'] == 'no']
# Out:
#                         label  ... present
# 2           Yoriko_Kawaguchi   ...      no
# 3           Yoriko_Kawaguchi   ...      no
# 4           Yoriko_Kawaguchi   ...      no
# 5           Yoriko_Kawaguchi   ...      no
# 6           Yoriko_Kawaguchi   ...      no
# ...                       ...  ...     ...
# 50136  Arnold_Schwarzenegger   ...      no
# 50137          George_W_Bush   ...      no
# 50138          George_W_Bush   ...      no
# 50139          George_W_Bush   ...      no
# 50140          George_W_Bush   ...      no
#
# [15933 rows x 4 columns]

# %%
train_df.loc[train_df['label_count']>260]
# Out:
#                    label                           image  label_count present
# 0      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304     yes
# 1      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304     yes
# 2      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304      no
# 3      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304      no
# 4      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304      no
# ...                  ...                             ...          ...     ...
# 50174      Ariel_Sharon       Ariel_Sharon - _0_5054.jpg          270     yes
# 50175      Ariel_Sharon       Ariel_Sharon - _0_3336.jpg          270     yes
# 50176      Ariel_Sharon       Ariel_Sharon - _0_9667.jpg          270     yes
# 50177      Ariel_Sharon       Ariel_Sharon - _0_7802.jpg          270     yes
# 50178       Hugo_Chavez        Hugo_Chavez - _0_3009.jpg          296     yes
#
# [48025 rows x 4 columns]

# %%
final_training_df = train_df.sort_values('label', ascending = False).groupby('label').head(200)

# %%
len(final_training_df)
# Out:
# 32000

# %%
del train_df['present']

# %%
index = list(final_training_df.index)
len(index)
# Out:
# 32000

# %%
present = []
for i in train_df.index:
  if i in index:
    present.append('yes')
  else:
    present.append('no')
train_df['present'] = present
train_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                label                           image  label_count present
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304     yes
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304     yes
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304      no
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304      no
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304      no

# %%
test_df = train_df.loc[train_df['present'] == 'no']

# %%
len(combined_np)
# Out:
# 50179

# %%
len(train_df)
# Out:
# 48025

# %%
combined_df
# Out:
#                    label                           image  label_count
# 0      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304
# ...                  ...                             ...          ...
# 50174      Ariel_Sharon       Ariel_Sharon - _0_5054.jpg          270
# 50175      Ariel_Sharon       Ariel_Sharon - _0_3336.jpg          270
# 50176      Ariel_Sharon       Ariel_Sharon - _0_9667.jpg          270
# 50177      Ariel_Sharon       Ariel_Sharon - _0_7802.jpg          270
# 50178       Hugo_Chavez        Hugo_Chavez - _0_3009.jpg          296
#
# [50179 rows x 3 columns]

# %%
train_df
# Out:
#                    label                           image  label_count present
# 0      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304     yes
# 1      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304     yes
# 2      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304      no
# 3      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304      no
# 4      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304      no
# ...                  ...                             ...          ...     ...
# 50174      Ariel_Sharon       Ariel_Sharon - _0_5054.jpg          270     yes
# 50175      Ariel_Sharon       Ariel_Sharon - _0_3336.jpg          270     yes
# 50176      Ariel_Sharon       Ariel_Sharon - _0_9667.jpg          270     yes
# 50177      Ariel_Sharon       Ariel_Sharon - _0_7802.jpg          270     yes
# 50178       Hugo_Chavez        Hugo_Chavez - _0_3009.jpg          296     yes
#
# [48025 rows x 4 columns]

# %% [markdown]
# # Data Creation for the Experiments

# %%
len(combined_df)
# Out:
# 50179

# %%
len(combined_np)
# Out:
# 50179

# %%
combined_df
# Out:
#                    label                           image  label_count
# 0      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4      Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304
# ...                  ...                             ...          ...
# 50174      Ariel_Sharon       Ariel_Sharon - _0_5054.jpg          270
# 50175      Ariel_Sharon       Ariel_Sharon - _0_3336.jpg          270
# 50176      Ariel_Sharon       Ariel_Sharon - _0_9667.jpg          270
# 50177      Ariel_Sharon       Ariel_Sharon - _0_7802.jpg          270
# 50178       Hugo_Chavez        Hugo_Chavez - _0_3009.jpg          296
#
# [50179 rows x 3 columns]

# %%
experimental_data = combined_df.loc[combined_df['label_count']>260]

# %%
experimental_data.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
experimental_data['label'].nunique()
# Out:
# 160

# %%
experimental_data.tail()
# Out:
#                label                       image  label_count
# 50174  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg          270
# 50175  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg          270
# 50176  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg          270
# 50177  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg          270
# 50178   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg          296

# %%
len(experimental_data)
# Out:
# 48025

# %%
experimental_index = list(experimental_data.index)
len(experimental_index)
# Out:
# 48025

# %%
experimental_np = []
for i in experimental_index:
  experimental_np.append(combined_np[i])
len(experimental_np)
# Out:
# 48025

# %%
experimental_data.tail()
# Out:
#                label                       image  label_count
# 50174  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg          270
# 50175  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg          270
# 50176  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg          270
# 50177  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg          270
# 50178   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg          296

# %%
plt.imshow(experimental_np[-1])

# %%
plt.imshow(experimental_np[-2])

# %%
plt.imshow(experimental_np[-3])

# %%
experimental_df = experimental_data.reset_index(drop = True)
len(experimental_df)
# Out:
# 48025

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/test_data

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
# !ls
# Out:
# single_faces_data  test_data  training_data

# %%
os.mkdir('data_for_experiments')

# %%
# %cd data_for_experiments/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/data_for_experiments

# %%
experimental_data.to_csv('experimental_data.csv')
np.save('experimental_data', experimental_np, allow_pickle=True)

# %% [markdown]
# # Training Data Creation

# %%
experimental_df.tail()
# Out:
#                label                       image  label_count
# 48020  Ariel_Sharon   Ariel_Sharon - _0_5054.jpg          270
# 48021  Ariel_Sharon   Ariel_Sharon - _0_3336.jpg          270
# 48022  Ariel_Sharon   Ariel_Sharon - _0_9667.jpg          270
# 48023  Ariel_Sharon   Ariel_Sharon - _0_7802.jpg          270
# 48024   Hugo_Chavez    Hugo_Chavez - _0_3009.jpg          296

# %%
len(experimental_df)
# Out:
# 48025

# %%
len(experimental_np)
# Out:
# 48025

# %%
experimental_df['label'].nunique()
# Out:
# 160

# %%
training_df = experimental_df.sort_values('label', ascending = False).groupby('label').head(200)

# %%
len(training_df)
# Out:
# 32000

# %%
training_index = list(training_df.index)
len(training_index)
# Out:
# 32000

# %%
training_np = []
for i in training_index:
  training_np.append(experimental_np[i])
  #print(i)
len(training_np)
# Out:
# 32000

# %%
training_df.head()
# Out:
#                  label                           image  label_count
# 0    Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 201  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 209  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 208  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 206  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304

# %%
training_df = training_df.reset_index(drop = True)
training_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi     Yoriko_Kawaguchi - _0_78.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6229.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1960.jpg          304
# 4  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_735.jpg          304

# %%
plt.imshow(training_np[0])

# %%
training_df.tail()
# Out:
#                    label                           image  label_count
# 31995  Alejandro_Toledo   Alejandro_Toledo - _0_3915.jpg          303
# 31996  Alejandro_Toledo   Alejandro_Toledo - _0_2414.jpg          303
# 31997  Alejandro_Toledo    Alejandro_Toledo - _0_514.jpg          303
# 31998  Alejandro_Toledo   Alejandro_Toledo - _0_8306.jpg          303
# 31999  Alejandro_Toledo   Alejandro_Toledo - _0_6180.jpg          303

# %%
plt.imshow(training_np[31999])

# %%
plt.imshow(training_np[31998])

# %%
shuffled_training_df = training_df.sample(frac = 1)
shuffled_training_df.head()
# Out:
#                   label                         image  label_count
# 10389  Nestor_Kirchner   Nestor_Kirchner - _0_842.jpg          302
# 3716       Tiger_Woods      Tiger_Woods - _0_9656.jpg          311
# 26562   George_Clooney   George_Clooney - _0_4170.jpg          284
# 9030      Paul_Burrell     Paul_Burrell - _0_9419.jpg          277
# 24686     Hamid_Karzai     Hamid_Karzai - _0_1213.jpg          299

# %%
len(shuffled_training_df)
# Out:
# 32000

# %%
shuffled_training_index = list(shuffled_training_df.index)
len(shuffled_training_index)
# Out:
# 32000

# %%
shuffled_training_np = []
for i in shuffled_training_index:
  shuffled_training_np.append(training_np[i])
len(shuffled_training_np)
# Out:
# 32000

# %%
shuffled_training_df.head()
# Out:
#                   label                         image  label_count
# 10389  Nestor_Kirchner   Nestor_Kirchner - _0_842.jpg          302
# 3716       Tiger_Woods      Tiger_Woods - _0_9656.jpg          311
# 26562   George_Clooney   George_Clooney - _0_4170.jpg          284
# 9030      Paul_Burrell     Paul_Burrell - _0_9419.jpg          277
# 24686     Hamid_Karzai     Hamid_Karzai - _0_1213.jpg          299

# %%
shuffled_training_df = shuffled_training_df.reset_index(drop = True)
shuffled_training_df.head()
# Out:
#               label                         image  label_count
# 0  Nestor_Kirchner   Nestor_Kirchner - _0_842.jpg          302
# 1      Tiger_Woods      Tiger_Woods - _0_9656.jpg          311
# 2   George_Clooney   George_Clooney - _0_4170.jpg          284
# 3     Paul_Burrell     Paul_Burrell - _0_9419.jpg          277
# 4     Hamid_Karzai     Hamid_Karzai - _0_1213.jpg          299

# %%
plt.imshow(shuffled_training_np[0])

# %%
plt.imshow(shuffled_training_np[1])

# %%
fig, ax = plt.subplots(1, 5)
ax[0].imshow(shuffled_training_np[0])
ax[1].imshow(shuffled_training_np[1])
ax[2].imshow(shuffled_training_np[2])
ax[3].imshow(shuffled_training_np[3])
ax[4].imshow(shuffled_training_np[4])
plt.show()

# %%
shuffled_training_df.tail()
# Out:
#                       label                              image  label_count
# 31995           Jiri_Novak            Jiri_Novak - _0_9286.jpg          311
# 31996     George_Robertson      George_Robertson - _0_9116.jpg          297
# 31997          Ann_Veneman           Ann_Veneman - _0_2957.jpg          283
# 31998         Tommy_Franks           Tommy_Franks - _0_949.jpg          293
# 31999  John_Allen_Muhammad   John_Allen_Muhammad - _0_7386.jpg          261

# %%
fig, ax = plt.subplots(1, 5)
ax[0].imshow(shuffled_training_np[-1])
ax[1].imshow(shuffled_training_np[-2])
ax[2].imshow(shuffled_training_np[-3])
ax[3].imshow(shuffled_training_np[-4])
ax[4].imshow(shuffled_training_np[-5])
plt.show()

# %%
shuffled_training_label = []
for i in shuffled_training_df['label']:
  shuffled_training_label.append(i)
print(len(shuffled_training_label))
# Out:
# 32000

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/data_for_experiments

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
# %cd training_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/training_data

# %%
shuffled_training_df.to_csv('training_data.csv')
np.save('training_images', shuffled_training_np, allow_pickle=True)
np.save('training_labels', shuffled_training_label, allow_pickle=True)

# %%
pd.read_csv('training_data.csv').head()
# Out:
#    Unnamed: 0             label                         image  label_count
# 0           0  Nestor_Kirchner   Nestor_Kirchner - _0_842.jpg          302
# 1           1      Tiger_Woods      Tiger_Woods - _0_9656.jpg          311
# 2           2   George_Clooney   George_Clooney - _0_4170.jpg          284
# 3           3     Paul_Burrell     Paul_Burrell - _0_9419.jpg          277
# 4           4     Hamid_Karzai     Hamid_Karzai - _0_1213.jpg          299

# %%
fig, ax = plt.subplots(1,5)
for i in range(5):
  ax[i].imshow(np.load('training_images.npy', allow_pickle=True)[i])
  ax[i].set_xlabel(np.load('training_labels.npy', allow_pickle = True)[i])

# %% [markdown]
# # Test Data Creation

# %%
experimental_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_6007.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8892.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7536.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8708.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9563.jpg          304

# %%
len(experimental_df)
# Out:
# 48025

# %%
len(experimental_np)
# Out:
# 48025

# %%
pending_df = experimental_df.sort_values('label', ascending = False).groupby('label').tail(60)

# %%
len(pending_df)
# Out:
# 9600

# %%
pending_df.head()
# Out:
#                  label                           image  label_count
# 117  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_2549.jpg          304
# 116  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8800.jpg          304
# 115  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7875.jpg          304
# 114  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8270.jpg          304
# 113  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_3855.jpg          304

# %%
pending_df.tail()
# Out:
#                    label                           image  label_count
# 39223  Alejandro_Toledo    Alejandro_Toledo - _0_559.jpg          303
# 39222  Alejandro_Toledo   Alejandro_Toledo - _0_2295.jpg          303
# 39221  Alejandro_Toledo   Alejandro_Toledo - _0_4720.jpg          303
# 39220  Alejandro_Toledo   Alejandro_Toledo - _0_2201.jpg          303
# 39157  Alejandro_Toledo   Alejandro_Toledo - _0_8898.jpg          303

# %%
pending_index = list(pending_df.index)
len(pending_index)
# Out:
# 9600

# %%
pending_np = []
for i in pending_index:
  pending_np.append(experimental_np[i])
len(pending_np)
# Out:
# 9600

# %%
pending_df = pending_df.reset_index(drop = True)
pending_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_2549.jpg          304
# 1  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8800.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7875.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8270.jpg          304
# 4  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_3855.jpg          304

# %%
fig, ax = plt.subplots(1,5)
ax[0].imshow(pending_np[0])
ax[0].set_xlabel(pending_df['label'][0])
ax[1].imshow(pending_np[1])
ax[1].set_xlabel(pending_df['label'][1])
ax[2].imshow(pending_np[2])
ax[2].set_xlabel(pending_df['label'][2])
ax[3].imshow(pending_np[3])
ax[3].set_xlabel(pending_df['label'][3])
ax[4].imshow(pending_np[4])
ax[4].set_xlabel(pending_df['label'][4])
# Out:
# Text(0.5, 0, 'Yoriko_Kawaguchi ')

# %%
pending_df.tail()
# Out:
#                   label                           image  label_count
# 9595  Alejandro_Toledo    Alejandro_Toledo - _0_559.jpg          303
# 9596  Alejandro_Toledo   Alejandro_Toledo - _0_2295.jpg          303
# 9597  Alejandro_Toledo   Alejandro_Toledo - _0_4720.jpg          303
# 9598  Alejandro_Toledo   Alejandro_Toledo - _0_2201.jpg          303
# 9599  Alejandro_Toledo   Alejandro_Toledo - _0_8898.jpg          303

# %%
fig, ax = plt.subplots(1,5)
ax[0].imshow(pending_np[-1])
ax[0].set_xlabel(pending_df['label'][9599])
ax[1].imshow(pending_np[-2])
ax[1].set_xlabel(pending_df['label'][9598])
ax[2].imshow(pending_np[-3])
ax[2].set_xlabel(pending_df['label'][9597])
ax[3].imshow(pending_np[-4])
ax[3].set_xlabel(pending_df['label'][9596])
ax[4].imshow(pending_np[-5])
ax[4].set_xlabel(pending_df['label'][9595])
# Out:
# Text(0.5, 0, 'Alejandro_Toledo ')

# %%
test_df = pending_df.sort_values('label', ascending = False).groupby('label').head(50)

# %%
test_df.shape
# Out:
# (8000, 3)

# %%
test_index = list(test_df.index)
len(test_index)
# Out:
# 8000

# %%
test_np = []
for i in test_index:
  test_np.append(pending_np[i])
len(test_np)
# Out:
# 8000

# %%
test_df.head()
# Out:
#                 label                           image  label_count
# 0   Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_2549.jpg          304
# 31  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_885.jpg          304
# 33  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7998.jpg          304
# 34  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9995.jpg          304
# 35  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_835.jpg          304

# %%
test_df = test_df.reset_index(drop = True)

# %%
test_df.head()
# Out:
#                label                           image  label_count
# 0  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_2549.jpg          304
# 1  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_885.jpg          304
# 2  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7998.jpg          304
# 3  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9995.jpg          304
# 4  Yoriko_Kawaguchi    Yoriko_Kawaguchi - _0_835.jpg          304

# %%
fig, ax = plt.subplots(1, 5)
ax[0].imshow(test_np[0])
ax[0].set_xlabel(test_df['label'][0])
ax[1].imshow(test_np[1])
ax[1].set_xlabel(test_df['label'][1])
ax[2].imshow(test_np[2])
ax[2].set_xlabel(test_df['label'][2])
ax[3].imshow(test_np[3])
ax[3].set_xlabel(test_df['label'][3])
ax[4].imshow(test_np[4])
ax[4].set_xlabel(test_df['label'][4])
# Out:
# Text(0.5, 0, 'Yoriko_Kawaguchi ')

# %%
test_df['label'].value_counts(dropna = False)
# Out:
# Tony_Blair              50
# Roger_Federer           50
# Jason_Kidd              50
# Meryl_Streep            50
# Taha_Yassin_Ramadan     50
#                         ..
# Jean_Chretien           50
# Joschka_Fischer         50
# Bill_Simon              50
# Julie_Gerberding        50
# Jeb_Bush                50
# Name: label, Length: 160, dtype: int64

# %%
shuffled_test_df = test_df.sample(frac = 1)
shuffled_test_index = list(shuffled_test_df.index)
shuffled_test_np = []
for i in shuffled_test_index:
  shuffled_test_np.append(test_np[i])
shuffled_test_df = shuffled_test_df.reset_index(drop = True)
fig, ax = plt.subplots(1,4)
ax[0].imshow(shuffled_test_np[0])
ax[0].set_xlabel(shuffled_test_df['label'][0])
ax[1].imshow(shuffled_test_np[1])
ax[1].set_xlabel(shuffled_test_df['label'][1])
ax[2].imshow(shuffled_test_np[5000])
ax[2].set_xlabel(shuffled_test_df['label'][5000])
ax[3].imshow(shuffled_test_np[5001])
ax[3].set_xlabel(shuffled_test_df['label'][5001])
# Out:
# Text(0.5, 0, 'Jiang_Zemin ')

# %%
shuffled_test_df.tail()
# Out:
#                   label                            image  label_count
# 7995        Mohammed_Al  Mohammed_Al-Douri - _0_6339.jpg          299
# 7996      Vaclav_Havel        Vaclav_Havel - _0_4735.jpg          283
# 7997      Pete_Sampras        Pete_Sampras - _0_7136.jpg          296
# 7998  Richard_Gephardt    Richard_Gephardt - _0_3039.jpg          303
# 7999       Ann_Veneman         Ann_Veneman - _0_2864.jpg          283

# %%
plt.imshow(shuffled_test_np[7997])

# %%
shuffled_test_df['label'].nunique()
# Out:
# 160

# %%
shuffled_test_df['label'].value_counts(dropna = False)
# Out:
# Tony_Blair          50
# Roger_Federer       50
# Jason_Kidd          50
# Meryl_Streep        50
# James_Kelly         50
#                     ..
# Catherine_Zeta      50
# Jean_Chretien       50
# Joschka_Fischer     50
# Bill_Simon          50
# Jeb_Bush            50
# Name: label, Length: 160, dtype: int64

# %%
shuffled_test_label = [i for i in shuffled_test_df['label']]
len(shuffled_test_label)
# Out:
# 8000

# %%
plt.imshow(shuffled_test_np[7997])
plt.xlabel(shuffled_test_label[7997])
# Out:
# Text(0.5, 0, 'Pete_Sampras ')

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/training_data

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
# !ls
# Out:
# data_for_experiments  single_faces_data  test_data  training_data

# %%
# %cd test_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/test_data

# %%
shuffled_test_df.to_csv('test_data.csv')
np.save('test_images', shuffled_test_np, allow_pickle=True)
np.save('test_labels', shuffled_test_label, allow_pickle = True)

# %%
len(pd.read_csv('test_data.csv'))
# Out:
# 8000

# %%
len(np.load('test_images.npy', allow_pickle = True))
# Out:
# 8000

# %% [markdown]
# # Unseen Data

# %%
len(pending_df)
# Out:
# 9600

# %%
unseen_df = pending_df.sort_values('label', ascending = False).groupby('label').tail(10)

# %%
len(unseen_df)
# Out:
# 1600

# %%
unseen_df.head()
# Out:
#                 label                           image  label_count
# 26  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7284.jpg          304
# 25  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_9226.jpg          304
# 24  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_1627.jpg          304
# 23  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_7581.jpg          304
# 28  Yoriko_Kawaguchi   Yoriko_Kawaguchi - _0_8849.jpg          304

# %%
unseen_df.tail()
# Out:
#                   label                           image  label_count
# 9564  Alejandro_Toledo   Alejandro_Toledo - _0_4650.jpg          303
# 9565  Alejandro_Toledo    Alejandro_Toledo - _0_624.jpg          303
# 9566  Alejandro_Toledo    Alejandro_Toledo - _0_422.jpg          303
# 9567  Alejandro_Toledo   Alejandro_Toledo - _0_3541.jpg          303
# 9599  Alejandro_Toledo   Alejandro_Toledo - _0_8898.jpg          303

# %%
unseen_index = list(unseen_df.index)
len(unseen_index)
# Out:
# 1600

# %%
unseen_np = []
for i in unseen_index:
  unseen_np.append(pending_np[i])
len(unseen_np)
# Out:
# 1600

# %%
unseen_df = unseen_df.reset_index(drop = True)

# %%
shuffled_unseen_df = unseen_df.sample(frac = 1)
shuffled_unseen_index = list(shuffled_unseen_df.index)
shuffled_unseen_np = []
for i in shuffled_unseen_index:
  shuffled_unseen_np.append(unseen_np[i])
shuffled_unseen_df = shuffled_unseen_df.reset_index(drop = True)
fig, ax = plt.subplots(1,4)
ax[0].imshow(shuffled_unseen_np[0])
ax[0].set_xlabel(shuffled_unseen_df['label'][0])
ax[1].imshow(shuffled_unseen_np[1])
ax[1].set_xlabel(shuffled_unseen_df['label'][1])
ax[2].imshow(shuffled_unseen_np[1000])
ax[2].set_xlabel(shuffled_unseen_df['label'][1000])
ax[3].imshow(shuffled_unseen_np[1001])
ax[3].set_xlabel(shuffled_unseen_df['label'][1001])
# Out:
# Text(0.5, 0, 'Bill_Simon ')

# %%
shuffled_unseen_df.tail()
# Out:
#                        label                                image  label_count
# 1595               Kim_Ryong          Kim_Ryong-sung - _0_291.jpg          291
# 1596        Nestor_Kirchner         Nestor_Kirchner - _0_8466.jpg          302
# 1597  Nicanor_Duarte_Frutos   Nicanor_Duarte_Frutos - _0_3166.jpg          288
# 1598           Colin_Powell            Colin_Powell - _0_8157.jpg          311
# 1599       George_Robertson        George_Robertson - _0_1258.jpg          297

# %%
shuffled_unseen_label = [i for i in shuffled_unseen_df['label']]
len(shuffled_unseen_label)
plt.imshow(shuffled_test_np[501])
plt.xlabel(shuffled_test_label[501])
# Out:
# Text(0.5, 0, 'Michael_Jackson ')

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/test_data

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data

# %%
# !ls
# Out:
# data_for_experiments  single_faces_data  test_data  training_data

# %%
os.mkdir('unseen_data')

# %%
# %cd unseen_data/
# Out:
# /content/drive/My Drive/case studies 2/Final_Data/Final_Face_Data/unseen_data

# %%
shuffled_unseen_df.to_csv('unseen_data.csv')
np.save('unseen_images', shuffled_unseen_np, allow_pickle=True)
np.save('unseen_labels', shuffled_unseen_label, allow_pickle = True)
