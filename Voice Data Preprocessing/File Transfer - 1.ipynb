# %% [markdown]
# **This was done to transfer a good chunk of files from the directory Training_Images to two newly created directories namely Training_Images_2 and Training_Images_3. This was done due to timeout issues on the Training_Images directory as a result of it having too many images.**

# %% [markdown]
# # Setting up the paths

# %%
import os
import shutil

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
# %cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
# !ls

# %%
# %cd case\ studies\ 2
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
# !ls
# Out:
# Training_Images  Training_Images_2  Validation_Images

# %%
cd Training_Images_2/
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images_2

# %%
path2 = os.getcwd()

# %%
path2
# Out:
# '/content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images_2'

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
# %cd Training_Images/
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images

# %%
path1 = os.getcwd()

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
# %cd Training_Images/
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images

# %%
os.listdir(os.getcwd())[0:100]

# %% [markdown]
# # Moving in chunks of 10

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
for i in range(10):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

# %%
print(len(os.listdir(path2)))
# Out:
# 14081

# %% [markdown]
# # Moving in chunks of 20

# %%
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)

for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
for i in range(20):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path2)
print(len(os.listdir(path2)))
# Out:
# 14181
# 14281
# 14381
# 14481
# 14581
# 14681
# 14781
# 14881

# %% [markdown]
# # Moving in chunks of 30

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
os.mkdir('Training_Images_3')

# %%
# %cd Training_Images_3/
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images_3

# %%
path3 = os.getcwd()

# %%
path3
# Out:
# '/content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images_3'

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms

# %%
# %cd Training_Images/
# Out:
# /content/drive/My Drive/case studies 2/mel_spectrograms/Training_Images

# %%
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
# Out:
# 150
# 300
# 450
# 600
# 750
# 900
# 1050
# 1200

# %%
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
# Out:
# 1350
# 1500
# 1650
# 1800
# 1950
# 2100
# 2250
# 2400
# 2550
# 2700
# 2850
# 3000
# 3150
# 3300
# 3450
# 3600

# %%
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
# Out:
# 3750
# 3900
# 4050
# 4200
# 4350
# 4500
# 4650
# 4800
# 4950
# 5100
# 5250
# 5400
# 5550
# 5700
# 5850
# 6000
# 6150
# 6300
# 6450
# 6600
# 6750
# 6900
# 7050
# 7200
# 7350
# 7500
# 7650
# 7800
# 7950
# 8100
# 8250
# 8400

# %%
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
# Out:
# 8550
# 8700
# 8850
# 9000
# 9150
# 9300
# 9450
# 9600
# 9750
# 9900
# 10050
# 10200
# 10350
# 10500
# 10650
# 10800
# 10950
# 11100
# 11250
# 11400
# 11550
# 11700
# 11850
# 12000
# 12150
# 12300
# 12450
# 12600
# 12750
# 12900
# 13050
# 13200

# %%
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)

for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
for i in range(30):
  shutil.move(os.path.join(os.getcwd(), os.listdir(os.getcwd())[i]), path3)
print(len(os.listdir(path3)))
# Out:
# 13350
# 13500
# 13650
# 13800
# 13950
# 14100
# 14250
# 14400
# 14550
# 14700
# 14850
# 15000
# 15150
# 15300
# 15450
# 15600
# 15750
# 15900
# 16050
# 16200
# 16350
# 16500
# 16650
# 16800
# 16950
# 17100
# 17250
# 17400
# 17550
# 17700
# 17850
# 18000

# %%
len(os.listdir(os.getcwd()))
# Out:
# 49589
