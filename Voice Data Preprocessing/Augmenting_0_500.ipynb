# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
# %cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
# %cd case\ studies\ 2
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       '5-Concatenating Raw Waveforms.ipynb'
# '2-Gathering files information.ipynb'   Augmenting_0_500.ipynb
# '3-Data Pre-Processing.ipynb'	       'Face Dataset'
# '4-Gathering Raw Waveforms.ipynb'       raw_data

# %%
# %cd raw_data/
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       '5-Concatenating Raw Waveforms.ipynb'
# '2-Gathering files information.ipynb'   Augmenting_0_500.ipynb
# '3-Data Pre-Processing.ipynb'	       'Face Dataset'
# '4-Gathering Raw Waveforms.ipynb'       raw_data

# %%
# %cd raw_data/
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
# !ls
# Out:
# dev_clean	raw_waveforms  train-clean-100	     validation_file.npy
# dev_other	test_clean     training_file.npy     validation_speaker.npy
# files_data.npy	test_other     training_speaker.npy

# %%
import pandas as pd
import numpy as np
import os
import librosa
import librosa.display
import time
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
training_speaker = np.load('training_speaker.npy')

# %%
len(training_speaker)
# Out:
# 11150

# %%
training_speaker[0]
# Out:
# '103'

# %%
# !ls
# Out:
# dev_clean	raw_waveforms  train-clean-100	     validation_file.npy
# dev_other	test_clean     training_file.npy     validation_speaker.npy
# files_data.npy	test_other     training_speaker.npy

# %%
# %cd raw_waveforms/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
# !ls
# Out:
# data_0_500.npy	      data_6500_7000.npy   sr_3000_3500.npy
# data_10000_10500.npy  data_7000_7500.npy   sr_3500_4000.npy
# data_1000_1500.npy    data_7500_8000.npy   sr_4000_4500.npy
# data_10500_11000.npy  data_8000_8500.npy   sr_4500_5000.npy
# data_11000_rest.npy   data_8500_9000.npy   sr_5000_5500.npy
# data_1500_2000.npy    data_9000_9500.npy   sr_500_1000.npy
# data_2000_2500.npy    data_9500_10000.npy  sr_5500_6000.npy
# data_2500_3000.npy    raw_waveform.npy	   sr_6000_6500.npy
# data_3000_3500.npy    sr_0_500.npy	   sr_6500_7000.npy
# data_3500_4000.npy    sr_10000_10500.npy   sr_7000_7500.npy
# data_4000_4500.npy    sr_1000_1500.npy	   sr_7500_8000.npy
# data_4500_5000.npy    sr_10500_11000.npy   sr_8000_8500.npy
# data_5000_5500.npy    sr_11000_rest.npy    sr_8500_9000.npy
# data_500_1000.npy     sr_1500_2000.npy	   sr_9000_9500.npy
# data_5500_6000.npy    sr_2000_2500.npy	   sr_9500_10000.npy
# data_6000_6500.npy    sr_2500_3000.npy

# %%
sr_0_500 = np.load('sr_0_500.npy')
data_0_500 = np.load('data_0_500.npy', allow_pickle = True)

# %%
len(sr_0_500)
# Out:
# 500

# %%
len(data_0_500)
# Out:
# 500

# %%
speaker_0_500 = training_speaker[:500]
len(speaker_0_500)
# Out:
# 500

# %%
len(data_0_500[0])
# Out:
# 339681

# %%
sr_0_500[0]
# Out:
# 22050

# %%
duration = []
for i in range(len(sr_0_500)):
  time = len(data_0_500[i])/sr_0_500[i]
  duration.append(time)

# %%
len(duration)
# Out:
# 500

# %%
duration[0]
# Out:
# 15.405034013605443

# %%
np.array(duration).max()
# Out:
# 30.04

# %%
ipd.Audio(data_0_500[0][:sr_0_500[0]], rate = sr_0_500[0])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
S = librosa.feature.melspectrogram(y = data_0_500[0][:sr_0_500[0]], sr = sr_0_500[0])

# %%
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[1][:sr_0_500[1]], sr = sr_0_500[1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[1][sr_0_500[1]:(sr_0_500[1]*2)], sr = sr_0_500[1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[1][sr_0_500[1]*2:(sr_0_500[1]*3)], sr = sr_0_500[1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[-1][sr_0_500[-1]*2:(sr_0_500[-1]*3)], sr = sr_0_500[-1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[-1][:(sr_0_500[-1])], sr = sr_0_500[-1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
S = librosa.feature.melspectrogram(y = data_0_500[-1][(sr_0_500[-1]):(sr_0_500[-1])*2], sr = sr_0_500[-1])
librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')

# %%
# !ls
# Out:
# data_0_500.npy	      data_6500_7000.npy   sr_3000_3500.npy
# data_10000_10500.npy  data_7000_7500.npy   sr_3500_4000.npy
# data_1000_1500.npy    data_7500_8000.npy   sr_4000_4500.npy
# data_10500_11000.npy  data_8000_8500.npy   sr_4500_5000.npy
# data_11000_rest.npy   data_8500_9000.npy   sr_5000_5500.npy
# data_1500_2000.npy    data_9000_9500.npy   sr_500_1000.npy
# data_2000_2500.npy    data_9500_10000.npy  sr_5500_6000.npy
# data_2500_3000.npy    raw_waveform.npy	   sr_6000_6500.npy
# data_3000_3500.npy    sr_0_500.npy	   sr_6500_7000.npy
# data_3500_4000.npy    sr_10000_10500.npy   sr_7000_7500.npy
# data_4000_4500.npy    sr_1000_1500.npy	   sr_7500_8000.npy
# data_4500_5000.npy    sr_10500_11000.npy   sr_8000_8500.npy
# data_5000_5500.npy    sr_11000_rest.npy    sr_8500_9000.npy
# data_500_1000.npy     sr_1500_2000.npy	   sr_9000_9500.npy
# data_5500_6000.npy    sr_2000_2500.npy	   sr_9500_10000.npy
# data_6000_6500.npy    sr_2500_3000.npy

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
os.mkdir('Augmented_0_500')

# %%
# !ls
# Out:
# Augmented_0_500       data_6000_6500.npy   sr_2500_3000.npy
# data_0_500.npy	      data_6500_7000.npy   sr_3000_3500.npy
# data_10000_10500.npy  data_7000_7500.npy   sr_3500_4000.npy
# data_1000_1500.npy    data_7500_8000.npy   sr_4000_4500.npy
# data_10500_11000.npy  data_8000_8500.npy   sr_4500_5000.npy
# data_11000_rest.npy   data_8500_9000.npy   sr_5000_5500.npy
# data_1500_2000.npy    data_9000_9500.npy   sr_500_1000.npy
# data_2000_2500.npy    data_9500_10000.npy  sr_5500_6000.npy
# data_2500_3000.npy    raw_waveform.npy	   sr_6000_6500.npy
# data_3000_3500.npy    sr_0_500.npy	   sr_6500_7000.npy
# data_3500_4000.npy    sr_10000_10500.npy   sr_7000_7500.npy
# data_4000_4500.npy    sr_1000_1500.npy	   sr_7500_8000.npy
# data_4500_5000.npy    sr_10500_11000.npy   sr_8000_8500.npy
# data_5000_5500.npy    sr_11000_rest.npy    sr_8500_9000.npy
# data_500_1000.npy     sr_1500_2000.npy	   sr_9000_9500.npy
# data_5500_6000.npy    sr_2000_2500.npy	   sr_9500_10000.npy

# %%
# %cd Augmented_0_500/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms/Augmented_0_500

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms/Augmented_0_500

# %% [markdown]
# # Generating training data

# %%
filename = []
for i in range(len(speaker_0_500)):
  
  fig = plt.figure(figsize=[1,1])
  ax = fig.add_subplot(111)
  ax.axes.get_xaxis().set_visible(False)
  ax.axes.get_yaxis().set_visible(False)
  ax.set_frame_on(False)
  start = time.time()
  S = librosa.feature.melspectrogram(y = data_0_500[i][:sr_0_500[i]], sr = sr_0_500[i])
  librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
  file = str(speaker_0_500[i]) + '- 1 -' + str(i) + '.jpg'
  filename.append(file)
  plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
  plt.close()
  if len(filename)%10==0:
    print(len(filename))
    print(time.time()-start)
# Out:
# 10
# 0.06771540641784668
# 20
# 0.06756591796875
# 30
# 0.06641721725463867
# 40
# 0.06638550758361816
# 50
# 0.0707862377166748
# 60
# 0.06943988800048828
# 70
# 0.06788778305053711
# 80
# 0.07151675224304199
# 90
# 0.06789350509643555
# 100
# 0.06983542442321777
# 110
# 0.07259130477905273
# 120
# 0.0682220458984375
# 130
# 0.06898045539855957
# 140
# 0.06951427459716797
# 150
# 0.07811331748962402
# 160
# 0.06790566444396973
# 170
# 0.07170367240905762
# 180
# 0.06926512718200684
# 190
# 0.07040214538574219
# 200
# 0.06859183311462402
# 210
# 0.06928133964538574
# 220
# 0.07019901275634766
# 230
# 0.06853175163269043
# 240
# 0.07993888854980469
# 250
# 0.06936979293823242
# 260
# 0.06662511825561523
# 270
# 0.06691384315490723
# 280
# 0.06705141067504883
# 290
# 0.06862807273864746
# 300
# 0.07288932800292969
# 310
# 0.06827282905578613
# 320
# 0.07248210906982422
# 330
# 0.07042264938354492
# 340
# 0.07080507278442383
# 350
# 0.0754096508026123
# 360
# 0.10252618789672852
# 370
# 0.07024312019348145
# 380
# 0.0705115795135498
# 390
# 0.06785464286804199
# 400
# 0.06802153587341309
# 410
# 0.07324934005737305
# 420
# 0.06809258460998535
# 430
# 0.06859207153320312
# 440
# 0.06703853607177734
# 450
# 0.06853079795837402
# 460
# 0.06877017021179199
# 470
# 0.06560134887695312
# 480
# 0.06885266304016113
# 490
# 0.06886672973632812
# 500
# 0.06971120834350586

# %%
filename_2 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][sr_0_500[i]:(sr_0_500[i]*2)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 2 -' + str(i) + '.jpg'
    filename_2.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_2.append('error')

  if len(filename_2)%10==0:
    print(len(filename_2))
    print(time.time()-start)
# Out:
# 10
# 0.08520793914794922
# 20
# 0.08878684043884277
# 30
# 0.08815526962280273
# 40
# 0.08542633056640625
# 50
# 0.09064388275146484
# 60
# 0.09171152114868164
# 70
# 0.08728289604187012
# 80
# 0.09463644027709961
# 90
# 0.08668851852416992
# 100
# 0.0872337818145752
# 110
# 0.10284185409545898
# 120
# 0.08699607849121094
# 130
# 0.08748269081115723
# 140
# 0.08735036849975586
# 150
# 0.08723020553588867
# 160
# 0.08478713035583496
# 170
# 0.0894930362701416
# 180
# 0.09748959541320801
# 190
# 0.08763885498046875
# 200
# 0.08591628074645996
# 210
# 0.08631658554077148
# 220
# 0.08660030364990234
# 230
# 0.08813714981079102
# 240
# 0.08892130851745605
# 250
# 0.08743810653686523
# 260
# 0.08696246147155762
# 270
# 0.08734655380249023
# 280
# 0.3776881694793701
# 290
# 0.08683133125305176
# 300
# 0.09724760055541992
# 310
# 0.09042119979858398
# 320
# 0.08985424041748047
# 330
# 0.08626365661621094
# 340
# 0.08508706092834473
# 350
# 0.08981585502624512
# 360
# 0.0890805721282959
# 370
# 0.08762359619140625
# 380
# 0.10961699485778809
# 390
# 0.08345150947570801
# 400
# 0.08614015579223633
# 410
# 0.08685755729675293
# 420
# 0.0870826244354248
# 430
# 0.08679485321044922
# 440
# 0.08753204345703125
# 450
# 0.08669710159301758
# 460
# 0.08900856971740723
# 470
# 0.08467650413513184
# 480
# 0.0916299819946289
# 490
# 0.09023404121398926
# 500
# 0.0848076343536377

# %%
filename_3 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*2):(sr_0_500[i]*3)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 3 -' + str(i) + '.jpg'
    filename_3.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_3.append('error')

  if len(filename_3)%10==0:
    print(len(filename_3))
    print(time.time()-start)
# Out:
# 10
# 0.08985638618469238
# 20
# 0.0973055362701416
# 30
# 0.08598923683166504
# 40
# 0.1914217472076416
# 50
# 0.0873563289642334
# 60
# 0.1289825439453125
# 70
# 0.08764290809631348
# 80
# 0.10009050369262695
# 90
# 0.08739590644836426
# 100
# 0.0880582332611084
# 110
# 0.08677959442138672
# 120
# 0.0908052921295166
# 130
# 0.08977317810058594
# 140
# 0.08831286430358887
# 150
# 0.08681583404541016
# 160
# 0.08785319328308105
# 170
# 0.11322665214538574
# 180
# 0.08675146102905273
# 190
# 0.10182642936706543
# 200
# 0.08477354049682617
# 210
# 0.08934831619262695
# 220
# 0.09546899795532227
# 230
# 0.0884394645690918
# 240
# 0.09219741821289062
# 250
# 0.08615255355834961
# 260
# 0.08864688873291016
# 270
# 0.09035634994506836
# 280
# 0.08670639991760254
# 290
# 0.08898687362670898
# 300
# 0.08986282348632812
# 310
# 0.11607551574707031
# 320
# 0.08731532096862793
# 330
# 0.09159708023071289
# 340
# 0.08674001693725586
# 350
# 0.08855223655700684
# 360
# 0.09175419807434082
# 370
# 0.020967483520507812
# 380
# 0.4825863838195801
# 390
# 0.11245322227478027
# 400
# 0.11295199394226074
# 410
# 0.08600306510925293
# 420
# 0.08608579635620117
# 430
# 0.09466075897216797
# 440
# 0.09248232841491699
# 450
# 0.09447503089904785
# 460
# 0.07222104072570801
# 470
# 0.08980464935302734
# 480
# 0.08814477920532227
# 490
# 0.0871896743774414
# 500
# 0.09857916831970215

# %%
filename_4 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*3):(sr_0_500[i]*4)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 4 -' + str(i) + '.jpg'
    filename_4.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_4.append('error')

  if len(filename_4)%10==0:
    print(len(filename_4))
    print(time.time()-start)
# Out:
# 10
# 0.08618617057800293
# 20
# 0.08613824844360352
# 30
# 0.08716607093811035
# 40
# 0.08688092231750488
# 50
# 0.08589744567871094
# 60
# 0.0858469009399414
# 70
# 0.08472728729248047
# 80
# 0.22138762474060059
# 90
# 0.08628511428833008
# 100
# 0.08994078636169434
# 110
# 0.08765316009521484
# 120
# 0.08728981018066406
# 130
# 0.08727812767028809
# 140
# 0.08539342880249023
# 150
# 0.08987212181091309
# 160
# 0.08691215515136719
# 170
# 0.08570170402526855
# 180
# 0.08581686019897461
# 190
# 0.08749628067016602
# 200
# 0.09897351264953613
# 210
# 0.08619570732116699
# 220
# 0.08675217628479004
# 230
# 0.08582091331481934
# 240
# 0.08908605575561523
# 250
# 0.08581161499023438
# 260
# 0.09437680244445801
# 270
# 0.08924484252929688
# 280
# 0.08413553237915039
# 290
# 0.020780563354492188
# 300
# 0.11417365074157715
# 310
# 0.019652128219604492
# 320
# 0.08787941932678223
# 330
# 0.08987164497375488
# 340
# 0.09534263610839844
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# 350
# 0.09793663024902344
# 360
# 0.08868861198425293
# 370
# 0.020130157470703125
# 380
# 0.08693885803222656
# 390
# 0.1051950454711914
# 400
# 0.08814835548400879
# 410
# 0.08518338203430176
# 420
# 0.09245181083679199
# 430
# 0.08568787574768066
# 440
# 0.08827424049377441
# 450
# 0.08457183837890625
# 460
# 0.021132707595825195
# 470
# 0.020072460174560547
# 480
# 0.08953499794006348
# 490
# 0.08695244789123535
# 500
# 0.09197378158569336

# %%
filename_5 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*4):(sr_0_500[i]*5)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 5 -' + str(i) + '.jpg'
    filename_5.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_5.append('error')

  if len(filename_5)%50==0:
    print(len(filename_5))
    print(time.time()-start)
# Out:
# 50
# 0.08671402931213379
# 100
# 0.09174132347106934
# 150
# 0.11763286590576172
# 200
# 0.10224652290344238
# 250
# 0.06947755813598633
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# 300
# 0.08647489547729492
# 350
# 0.08889985084533691
# 400
# 0.10680103302001953
# 450
# 0.08768463134765625
# 500
# 0.0863335132598877

# %%
len(os.listdir(os.getcwd()))
# Out:
# 2364

# %%
filename_6 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*5):(sr_0_500[i]*6)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 6 -' + str(i) + '.jpg'
    filename_6.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_6.append('error')

  if len(filename_6)%50==0:
    print(len(filename_6))
    print(time.time()-start)
# Out:
# 50
# 0.0938727855682373
# 100
# 0.09810042381286621
# 150
# 0.0884256362915039
# 200
# 0.10603213310241699
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# 250
# 0.021332263946533203
# 300
# 0.08574771881103516
# 350
# 0.08739781379699707
# 400
# 0.08610701560974121
# 450
# 0.08690619468688965
# 500
# 0.09084343910217285

# %%
len(os.listdir(os.getcwd()))
# Out:
# 2744

# %%
plt.close()

# %%
filename_7 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*6):(sr_0_500[i]*7)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 7 -' + str(i) + '.jpg'
    filename_7.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_7.append('error')

  if len(filename_7)%50==0:
    print(len(filename_7))
    print(time.time()-start)
# Out:
# 50
# 0.09349465370178223
# 100
# 0.08401727676391602
# 150
# 0.0876624584197998
# 200
# 0.08970522880554199
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# 250
# 0.019890546798706055
# 300
# 0.08855628967285156
# 350
# 0.019926786422729492
# 400
# 0.08619999885559082
# 450
# 0.08881664276123047
# 500
# 0.08634638786315918

# %%
plt.close()

# %%
filename_8 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*7):(sr_0_500[i]*8)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 8 -' + str(i) + '.jpg'
    filename_8.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_8.append('error')

  if len(filename_8)%50==0:
    print(len(filename_8))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.08611655235290527
# 100
# 0.08529949188232422
# 150
# 0.08831214904785156
# 200
# 0.08546161651611328
# 250
# 0.02165842056274414
# 300
# 0.08502030372619629
# 350
# 0.021321535110473633
# 400
# 0.0872199535369873
# 450
# 0.09869599342346191
# 500
# 0.0796213150024414

# %%
len(os.listdir(os.getcwd()))
# Out:
# 3416

# %%
filename_9 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*8):(sr_0_500[i]*9)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 9 -' + str(i) + '.jpg'
    filename_9.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_9.append('error')

  if len(filename_9)%50==0:
    print(len(filename_9))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.09676814079284668
# 100
# 0.08688592910766602
# 150
# 0.09080719947814941
# 200
# 0.09022212028503418
# 250
# 0.021004199981689453
# 300
# 0.08561921119689941
# 350
# 0.02224254608154297
# 400
# 0.0836784839630127
# 450
# 0.0873250961303711
# 500
# 0.07643342018127441

# %%
filename_10 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*9):(sr_0_500[i]*10)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 10 -' + str(i) + '.jpg'
    filename_10.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_10.append('error')

  if len(filename_10)%50==0:
    print(len(filename_10))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.08151745796203613
# 100
# 0.0929718017578125
# 150
# 0.08837199211120605
# 200
# 0.08711671829223633
# 250
# 0.020659208297729492
# 300
# 0.08629894256591797
# 350
# 0.020315885543823242
# 400
# 0.08956766128540039
# 450
# 0.08421516418457031
# 500
# 0.07726240158081055

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
# !ls
# Out:
# data_0_500.npy	      data_6500_7000.npy   sr_3000_3500.npy
# data_10000_10500.npy  data_7000_7500.npy   sr_3500_4000.npy
# data_1000_1500.npy    data_7500_8000.npy   sr_4000_4500.npy
# data_10500_11000.npy  data_8000_8500.npy   sr_4500_5000.npy
# data_11000_rest.npy   data_8500_9000.npy   sr_5000_5500.npy
# data_1500_2000.npy    data_9000_9500.npy   sr_500_1000.npy
# data_2000_2500.npy    data_9500_10000.npy  sr_5500_6000.npy
# data_2500_3000.npy    raw_waveform.npy	   sr_6000_6500.npy
# data_3000_3500.npy    sr_0_500.npy	   sr_6500_7000.npy
# data_3500_4000.npy    sr_10000_10500.npy   sr_7000_7500.npy
# data_4000_4500.npy    sr_1000_1500.npy	   sr_7500_8000.npy
# data_4500_5000.npy    sr_10500_11000.npy   sr_8000_8500.npy
# data_5000_5500.npy    sr_11000_rest.npy    sr_8500_9000.npy
# data_500_1000.npy     sr_1500_2000.npy	   sr_9000_9500.npy
# data_5500_6000.npy    sr_2000_2500.npy	   sr_9500_10000.npy
# data_6000_6500.npy    sr_2500_3000.npy	   Training_Images

# %% [markdown]
# # Generating validation data

# %%
os.mkdir('Validation_Images')

# %%
# !ls
# Out:
# data_0_500.npy	      data_7000_7500.npy   sr_4000_4500.npy
# data_10000_10500.npy  data_7500_8000.npy   sr_4500_5000.npy
# data_1000_1500.npy    data_8000_8500.npy   sr_5000_5500.npy
# data_10500_11000.npy  data_8500_9000.npy   sr_500_1000.npy
# data_11000_rest.npy   data_9000_9500.npy   sr_5500_6000.npy
# data_1500_2000.npy    data_9500_10000.npy  sr_6000_6500.npy
# data_2000_2500.npy    raw_waveform.npy	   sr_6500_7000.npy
# data_2500_3000.npy    sr_0_500.npy	   sr_7000_7500.npy
# data_3000_3500.npy    sr_10000_10500.npy   sr_7500_8000.npy
# data_3500_4000.npy    sr_1000_1500.npy	   sr_8000_8500.npy
# data_4000_4500.npy    sr_10500_11000.npy   sr_8500_9000.npy
# data_4500_5000.npy    sr_11000_rest.npy    sr_9000_9500.npy
# data_5000_5500.npy    sr_1500_2000.npy	   sr_9500_10000.npy
# data_500_1000.npy     sr_2000_2500.npy	   Training_Images
# data_5500_6000.npy    sr_2500_3000.npy	   Validation_Images
# data_6000_6500.npy    sr_3000_3500.npy
# data_6500_7000.npy    sr_3500_4000.npy

# %%
# %cd Validation_Images/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms/Validation_Images

# %%
filename_11 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*10):(sr_0_500[i]*11)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 11 -' + str(i) + '.jpg'
    filename_11.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_11.append('error')

  if len(filename_11)%50==0:
    print(len(filename_11))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.08656549453735352
# 100
# 0.22303009033203125
# 150
# 0.09185504913330078
# 200
# 0.08704614639282227
# 250
# 0.019846200942993164
# 300
# 0.12970876693725586
# 350
# 0.01995563507080078
# 400
# 0.08472537994384766
# 450
# 0.08652472496032715
# 500
# 0.09131479263305664

# %%
len(os.listdir(os.getcwd()))
# Out:
# 263

# %%
filename_12 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*11):(sr_0_500[i]*12)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 12 -' + str(i) + '.jpg'
    filename_12.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_12.append('error')

  if len(filename_12)%50==0:
    print(len(filename_12))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.08672881126403809
# 100
# 0.09256458282470703
# 150
# 0.08425569534301758
# 200
# 0.08452486991882324
# 250
# 0.01962137222290039
# 300
# 0.09066319465637207
# 350
# 0.02062249183654785
# 400
# 0.08500003814697266
# 450
# 0.08684158325195312
# 500
# 0.530315637588501

# %%
filename_13 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*12):(sr_0_500[i]*13)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 13 -' + str(i) + '.jpg'
    filename_13.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_13.append('error')

  if len(filename_13)%50==0:
    print(len(filename_13))
    print(len(os.listdir(os.getcwd())))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 558
# 0.09703373908996582
# 100
# 590
# 0.10070323944091797
# 150
# 632
# 0.0948801040649414
# 200
# 674
# 0.09320640563964844
# 250
# 682
# 0.027350187301635742
# 300
# 686
# 0.10245609283447266
# 350
# 697
# 0.04016518592834473
# 400
# 708
# 0.09692907333374023
# 450
# 744
# 0.10109972953796387
# 500
# 746
# 0.019665002822875977

# %%
filename_14 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*13):(sr_0_500[i]*14)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 14 -' + str(i) + '.jpg'
    filename_14.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_14.append('error')

  if len(filename_14)%50==0:
    print(len(filename_14))
    print(len(os.listdir(os.getcwd())))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 788
# 0.08597302436828613
# 100
# 818
# 0.09434938430786133
# 150
# 858
# 0.08744215965270996
# 200
# 895
# 0.08489465713500977
# 250
# 903
# 0.03087925910949707
# 300
# 906
# 0.10065150260925293
# 350
# 916
# 0.029953479766845703
# 400
# 927
# 0.10204958915710449
# 450
# 958
# 0.09911918640136719
# 500
# 960
# 0.022668838500976562

# %%
filename_15 = []
for i in range(len(speaker_0_500)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_0_500[i][(sr_0_500[i]*14):(sr_0_500[i]*15)], sr = sr_0_500[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_0_500[i]) + '- 15 -' + str(i) + '.jpg'
    filename_15.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_15.append('error')

  if len(filename_15)%50==0:
    print(len(filename_15))
    print(len(os.listdir(os.getcwd())))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 998
# 0.030966997146606445
# 100
# 1020
# 0.09399914741516113
# 150
# 1052
# 0.03551506996154785
# 200
# 1079
# 0.03190732002258301
# 250
# 1084
# 0.03328394889831543
# 300
# 1085
# 0.09397125244140625
# 350
# 1093
# 0.0334782600402832
# 400
# 1103
# 0.480053186416626
# 450
# 1131
# 0.09684252738952637
# 500
# 1133
# 0.021888256072998047
