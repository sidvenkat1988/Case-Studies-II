# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
# %cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
# %cd case\ studies\ 2
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
# '1-Gathering Data.ipynb'	       '5-Concatenating Raw Waveforms.ipynb'
# '2-Gathering files information.ipynb'  'Data Augmentation'
# '3-Data Pre-Processing.ipynb'	       'Face Dataset'
# '4-Gathering Raw Waveforms.ipynb'       raw_data

# %%
# %cd raw_data/
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
# !ls
# Out:
# dev_clean	raw_waveforms  train-clean-100	     validation_file.npy
# dev_other	test_clean     training_file.npy     validation_speaker.npy
# files_data.npy	test_other     training_speaker.npy

# %%
# %cd raw_waveforms/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
# !ls
# Out:
# data_0_500.npy	      data_7000_7500.npy   sr_4000_4500.npy
# data_10000_10500.npy  data_7500_8000.npy   sr_4500_5000.npy
# data_1000_1500.npy    data_8000_8500.npy   sr_5000_5500.npy
# data_10500_11000.npy  data_8500_9000.npy   sr_500_1000.npy
# data_11000_rest.npy   data_9000_9500.npy   sr_5500_6000.npy
# data_1500_2000.npy    data_9500_10000.npy  sr_6000_6500.npy
# data_2000_2500.npy    raw_waveform.npy	   sr_6500_7000.npy
# data_2500_3000.npy    sr_0_500.npy	   sr_7000_7500.npy
# data_3000_3500.npy    sr_10000_10500.npy   sr_7500_8000.npy
# data_3500_4000.npy    sr_1000_1500.npy	   sr_8000_8500.npy
# data_4000_4500.npy    sr_10500_11000.npy   sr_8500_9000.npy
# data_4500_5000.npy    sr_11000_rest.npy    sr_9000_9500.npy
# data_5000_5500.npy    sr_1500_2000.npy	   sr_9500_10000.npy
# data_500_1000.npy     sr_2000_2500.npy	   Training_Images
# data_5500_6000.npy    sr_2500_3000.npy	   Validation_Images
# data_6000_6500.npy    sr_3000_3500.npy
# ...

# %% [markdown]
# # Data Selection for Augmentation

# %%
import pandas as pd
import numpy as np
import os
import librosa
import librosa.display
import time
import matplotlib.pyplot as plt

# %%
data_500_1000 = np.load('data_500_1000.npy', allow_pickle = True)
sr_500_1000 = np.load('sr_500_1000.npy')

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
# !ls
# Out:
# dev_clean	raw_waveforms  train-clean-100	     validation_file.npy
# dev_other	test_clean     training_file.npy     validation_speaker.npy
# files_data.npy	test_other     training_speaker.npy

# %%
training_speaker = np.load('training_speaker.npy')

# %%
len(training_speaker)
# Out:
# 11150

# %%
speaker_500_1000 = training_speaker[500:1000]

# %%
len(data_500_1000)
# Out:
# 500

# %%
len(sr_500_1000)
# Out:
# 500

# %%
len(speaker_500_1000)
# Out:
# 500

# %%
# !ls
# Out:
# dev_clean	raw_waveforms  train-clean-100	     validation_file.npy
# dev_other	test_clean     training_file.npy     validation_speaker.npy
# files_data.npy	test_other     training_speaker.npy

# %%
# %cd raw_waveforms/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
# !ls
# Out:
# data_0_500.npy	      data_7000_7500.npy   sr_4000_4500.npy
# data_10000_10500.npy  data_7500_8000.npy   sr_4500_5000.npy
# data_1000_1500.npy    data_8000_8500.npy   sr_5000_5500.npy
# data_10500_11000.npy  data_8500_9000.npy   sr_500_1000.npy
# data_11000_rest.npy   data_9000_9500.npy   sr_5500_6000.npy
# data_1500_2000.npy    data_9500_10000.npy  sr_6000_6500.npy
# data_2000_2500.npy    raw_waveform.npy	   sr_6500_7000.npy
# data_2500_3000.npy    sr_0_500.npy	   sr_7000_7500.npy
# data_3000_3500.npy    sr_10000_10500.npy   sr_7500_8000.npy
# data_3500_4000.npy    sr_1000_1500.npy	   sr_8000_8500.npy
# data_4000_4500.npy    sr_10500_11000.npy   sr_8500_9000.npy
# data_4500_5000.npy    sr_11000_rest.npy    sr_9000_9500.npy
# data_5000_5500.npy    sr_1500_2000.npy	   sr_9500_10000.npy
# data_500_1000.npy     sr_2000_2500.npy	   Training_Images
# data_5500_6000.npy    sr_2500_3000.npy	   Validation_Images
# data_6000_6500.npy    sr_3000_3500.npy
# ...

# %%
# %cd Training_Images/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms/Training_Images

# %%
len(os.listdir(os.getcwd()))
# Out:
# 4002

# %% [markdown]
# # Generating Training Images

# %%
filename_1 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][:sr_500_1000[i]], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 1 -' + str(i) + '.jpg'
    filename_1.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_1.append('error')

  if len(filename_1)%50==0:
    print(len(filename_1))
    print(time.time()-start)
  plt.close()
# Out:
# 50
# 0.07999014854431152
# 100
# 0.07832837104797363
# 150
# 0.07964611053466797
# 200
# 0.08109259605407715
# 250
# 0.07923150062561035
# 300
# 0.08010458946228027
# 350
# 0.0792536735534668
# 400
# 0.07997298240661621
# 450
# 0.08128595352172852
# 500
# 0.07969546318054199

# %%
len(os.listdir(os.getcwd()))
# Out:
# 4502

# %%
filename_2 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]):(sr_500_1000[i]*2)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 2 -' + str(i) + '.jpg'
    filename_2.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_2.append('error')

  if len(filename_2)%50==0:
    print(len(filename_2))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.08121299743652344
# 4552
# 100
# 0.07920551300048828
# 4602
# 150
# 0.07953572273254395
# 4652
# 200
# 0.08003950119018555
# 4702
# 250
# 0.07907271385192871
# 4752
# 300
# 0.08086133003234863
# 4802
# 350
# 0.08056449890136719
# 4852
# 400
# 0.07988429069519043
# 4902
# 450
# 0.07938122749328613
# 4952
# 500
# 0.0794680118560791
# 5002

# %%
filename_3 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*2):(sr_500_1000[i]*3)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 3 -' + str(i) + '.jpg'
    filename_3.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_3.append('error')

  if len(filename_3)%50==0:
    print(len(filename_3))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.08142805099487305
# 5052
# 100
# 0.07223010063171387
# 5099
# 150
# 0.07806992530822754
# 5149
# 200
# 0.08016061782836914
# 5199
# 250
# 0.07850861549377441
# 5249
# 300
# 0.07895374298095703
# 5299
# 350
# 0.05375981330871582
# 5349
# 400
# 0.08875584602355957
# 5399
# 450
# 0.07867813110351562
# 5449
# 500
# 0.0790550708770752
# 5499

# %%
filename_4 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*3):(sr_500_1000[i]*4)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 4 -' + str(i) + '.jpg'
    filename_4.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_4.append('error')

  if len(filename_4)%50==0:
    print(len(filename_4))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.0796964168548584
# 5549
# 100
# 0.07895040512084961
# 5593
# 150
# 0.07907843589782715
# 5641
# 200
# 0.08103656768798828
# 5690
# 250
# 0.07985687255859375
# 5738
# 300
# 0.07873868942260742
# 5788
# 350
# 0.0177001953125
# 5828
# 400
# 0.0798192024230957
# 5876
# 450
# 0.08194637298583984
# 5925
# 500
# 0.08070206642150879
# 5975

# %%
filename_5 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*4):(sr_500_1000[i]*5)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 5 -' + str(i) + '.jpg'
    filename_5.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_5.append('error')

  if len(filename_5)%50==0:
    print(len(filename_5))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.07811570167541504
# 6025
# 100
# 0.07886791229248047
# 6067
# 150
# 0.07709956169128418
# 6107
# 200
# 0.08003878593444824
# 6152
# 250
# 0.07748198509216309
# 6200
# 300
# 0.07932162284851074
# 6249
# 350
# 0.016442537307739258
# 6281
# 400
# 0.08219528198242188
# 6327
# 450
# 0.07938027381896973
# 6373
# 500
# 0.08058500289916992
# 6422

# %%
filename_6 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*5):(sr_500_1000[i]*6)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 6 -' + str(i) + '.jpg'
    filename_6.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_6.append('error')

  if len(filename_6)%50==0:
    print(len(filename_6))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.07933330535888672
# 6472
# 100
# 0.0699617862701416
# 6503
# 150
# 0.016148805618286133
# 6536
# 200
# 0.07937073707580566
# 6577
# 250
# 0.08031058311462402
# 6623
# 300
# 0.07937145233154297
# 6671
# 350
# 0.01642918586730957
# 6693
# 400
# 0.08223152160644531
# 6737
# 450
# 0.08221054077148438
# 6778
# 500
# 0.08024406433105469
# 6826

# %%
filename_7 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*6):(sr_500_1000[i]*7)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 7 -' + str(i) + '.jpg'
    filename_7.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_7.append('error')

  if len(filename_7)%50==0:
    print(len(filename_7))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.07921457290649414
# 6876
# 100
# 0.015759944915771484
# 6895
# 150
# 0.016352415084838867
# 6921
# 200
# 0.0789189338684082
# 6955
# 250
# 0.07979464530944824
# 7000
# 300
# 0.08313822746276855
# 7048
# 350
# 0.016175508499145508
# 7067
# 400
# 0.08178043365478516
# 7110
# 450
# 0.07860660552978516
# 7150
# 500
# 0.07852458953857422
# 7198

# %%
filename_8 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*7):(sr_500_1000[i]*8)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 8 -' + str(i) + '.jpg'
    filename_8.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_8.append('error')

  if len(filename_8)%50==0:
    print(len(filename_8))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.08074283599853516
# 7248
# 100
# 0.01578831672668457
# 7263
# 150
# 0.016217708587646484
# 7283
# 200
# 0.07924294471740723
# 7312
# 250
# 0.08463072776794434
# 7354
# 300
# 0.08115434646606445
# 7402
# 350
# 0.01608896255493164
# 7415
# 400
# 0.08094263076782227
# 7457
# 450
# 0.07918643951416016
# 7496
# 500
# 0.10599207878112793
# 7544

# %%
filename_9 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*8):(sr_500_1000[i]*9)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 9 -' + str(i) + '.jpg'
    filename_9.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_9.append('error')

  if len(filename_9)%50==0:
    print(len(filename_9))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.08051347732543945
# 7594
# 100
# 0.015612125396728516
# 7605
# 150
# 0.016566753387451172
# 7621
# 200
# 0.08154582977294922
# 7641
# 250
# 0.07793498039245605
# 7681
# 300
# 0.08332061767578125
# 7729
# 350
# 0.017281532287597656
# 7740
# 400
# 0.08787918090820312
# 7780
# 450
# 0.08078289031982422
# 7817
# 500
# 0.08222770690917969
# 7863

# %%
filename_10 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*9):(sr_500_1000[i]*10)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 10 -' + str(i) + '.jpg'
    filename_10.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_10.append('error')

  if len(filename_10)%50==0:
    print(len(filename_10))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.08024239540100098
# 7913
# 100
# 0.016121625900268555
# 7920
# 150
# 0.01653742790222168
# 7931
# 200
# 0.07427692413330078
# 7949
# 250
# 0.07897734642028809
# 7988
# 300
# 0.08131623268127441
# 8035
# 350
# 0.011162519454956055
# 8043
# 400
# 0.08234381675720215
# 8082
# 450
# 0.08034205436706543
# 8114
# 500
# 0.08175015449523926
# 8160

# %% [markdown]
# # Generating Validation Data

# %%
# %cd ..
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms

# %%
# !ls
# Out:
# data_0_500.npy	      data_7000_7500.npy   sr_4000_4500.npy
# data_10000_10500.npy  data_7500_8000.npy   sr_4500_5000.npy
# data_1000_1500.npy    data_8000_8500.npy   sr_5000_5500.npy
# data_10500_11000.npy  data_8500_9000.npy   sr_500_1000.npy
# data_11000_rest.npy   data_9000_9500.npy   sr_5500_6000.npy
# data_1500_2000.npy    data_9500_10000.npy  sr_6000_6500.npy
# data_2000_2500.npy    raw_waveform.npy	   sr_6500_7000.npy
# data_2500_3000.npy    sr_0_500.npy	   sr_7000_7500.npy
# data_3000_3500.npy    sr_10000_10500.npy   sr_7500_8000.npy
# data_3500_4000.npy    sr_1000_1500.npy	   sr_8000_8500.npy
# data_4000_4500.npy    sr_10500_11000.npy   sr_8500_9000.npy
# data_4500_5000.npy    sr_11000_rest.npy    sr_9000_9500.npy
# data_5000_5500.npy    sr_1500_2000.npy	   sr_9500_10000.npy
# data_500_1000.npy     sr_2000_2500.npy	   Training_Images
# data_5500_6000.npy    sr_2500_3000.npy	   Validation_Images
# data_6000_6500.npy    sr_3000_3500.npy
# ...

# %%
# %cd Validation_Images/
# Out:
# /content/drive/My Drive/case studies 2/raw_data/raw_waveforms/Validation_Images

# %%
filename_11 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*10):(sr_500_1000[i]*11)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 11 -' + str(i) + '.jpg'
    filename_11.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_11.append('error')

  if len(filename_11)%50==0:
    print(len(filename_11))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.07952666282653809
# 1182
# 100
# 0.016451358795166016
# 1187
# 150
# 0.016638755798339844
# 1196
# 200
# 0.017505168914794922
# 1209
# 250
# 0.07882165908813477
# 1247
# 300
# 0.08050990104675293
# 1293
# 350
# 0.01063990592956543
# 1298
# 400
# 0.0802302360534668
# 1337
# 450
# 0.08351421356201172
# 1367
# 500
# 0.07969260215759277
# 1413

# %%
filename_12 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*11):(sr_500_1000[i]*12)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 12 -' + str(i) + '.jpg'
    filename_12.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_12.append('error')

  if len(filename_12)%50==0:
    print(len(filename_12))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.09978413581848145
# 1461
# 100
# 0.017183303833007812
# 1465
# 150
# 0.011205434799194336
# 1472
# 200
# 0.01846933364868164
# 1482
# 250
# 0.08029890060424805
# 1519
# 300
# 0.08470273017883301
# 1564
# 350
# 0.012988090515136719
# 1568
# 400
# 0.08018279075622559
# 1605
# 450
# 0.08095431327819824
# 1632
# 500
# 0.07973265647888184
# 1675

# %%
filename_13 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*12):(sr_500_1000[i]*13)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 13 -' + str(i) + '.jpg'
    filename_13.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_13.append('error')

  if len(filename_13)%50==0:
    print(len(filename_13))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.0685124397277832
# 1720
# 100
# 0.016170978546142578
# 1724
# 150
# 0.1904289722442627
# 1728
# 200
# 0.016744136810302734
# 1737
# 250
# 0.08007216453552246
# 1774
# 300
# 0.07799911499023438
# 1816
# 350
# 0.010543346405029297
# 1819
# 400
# 0.10698652267456055
# 1853
# 450
# 0.05597114562988281
# 1875
# 500
# 0.07979846000671387
# 1915

# %%
filename_14 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*13):(sr_500_1000[i]*14)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 14 -' + str(i) + '.jpg'
    filename_14.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_14.append('error')

  if len(filename_14)%50==0:
    print(len(filename_14))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.01657843589782715
# 1956
# 100
# 0.024729490280151367
# 1959
# 150
# 0.2026684284210205
# 1962
# 200
# 0.01145482063293457
# 1969
# 250
# 0.07919931411743164
# 2004
# 300
# 0.08126330375671387
# 2041
# 350
# 0.010408639907836914
# 2044
# 400
# 0.07970356941223145
# 2072
# 450
# 0.016103267669677734
# 2088
# 500
# 0.07899045944213867
# 2123

# %%
filename_15 = []
for i in range(len(speaker_500_1000)):
  start = time.time()
  try:
    fig = plt.figure(figsize=[1,1])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y = data_500_1000[i][(sr_500_1000[i]*14):(sr_500_1000[i]*15)], sr = sr_500_1000[i])
    librosa.display.specshow(librosa.power_to_db(S, ref = np.max), y_axis = 'linear')
    file = str(speaker_500_1000[i]) + '- 15 -' + str(i) + '.jpg'
    filename_15.append(file)
    plt.savefig(file, dpi = 500, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
  except Exception as e:
    filename_15.append('error')

  if len(filename_15)%50==0:
    print(len(filename_15))
    print(time.time()-start)
    print(len(os.listdir(os.getcwd())))
  plt.close()
# Out:
# 50
# 0.016180753707885742
# 2155
# 100
# 0.01047515869140625
# 2157
# 150
# 0.010655641555786133
# 2160
# 200
# 0.01033473014831543
# 2164
# 250
# 0.08149123191833496
# 2194
# 300
# 0.0765080451965332
# 2222
# 350
# 0.01027679443359375
# 2224
# 400
# 0.07760930061340332
# 2247
# 450
# 0.01681995391845703
# 2258
# 500
# 0.05571603775024414
# 2283
