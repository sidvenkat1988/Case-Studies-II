# %% [markdown]
# # Gathering Data

# %% [markdown]
# Here are the steps involved in gathering data from the [LibriSpeech ASR corpus](http://www.openslr.org/12/). The first five zipped files were downloaded.

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/
# Out:
# /content/drive

# %%
# !ls
# Out:
# 'My Drive'

# %%
# %cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
# !ls

# %%
# %cd case\ studies\ 2
# Out:
# /content/drive/My Drive/case studies 2

# %%
# !ls
# Out:
#  autoencoder_images.npy  'main data'	        speaker.npy
#  dummy.npy		  original_data_16000   Untitled0.ipynb

# %%
import os
import shutil

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/case studies 2'

# %%
os.mkdir(os.path.join(os.getcwd(), 'raw_data'))

# %%
# !ls
# Out:
#  autoencoder_images.npy  'main data'	        raw_data      Untitled0.ipynb
#  dummy.npy		  original_data_16000   speaker.npy

# %%
# %cd raw_data/
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
# !sudo wget http://www.openslr.org/resources/12/dev-clean.tar.gz
# Out:
# --2020-03-01 08:45:53--  http://www.openslr.org/resources/12/dev-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 337926286 (322M) [application/x-gzip]
# Saving to: ‘dev-clean.tar.gz’
#
# dev-clean.tar.gz    100%[===================>] 322.27M  9.48MB/s    in 36s
#
# 2020-03-01 08:46:29 (9.03 MB/s) - ‘dev-clean.tar.gz’ saved [337926286/337926286]

# %%
# !ls
# Out:
# dev-clean.tar.gz

# %%
# !sudo tar zxf dev-clean.tar.gz

# %%
# !ls
# Out:
# dev-clean.tar.gz  LibriSpeech

# %%
# !sudo rm -rf dev-clean.tar.gz

# %%
# !ls
# Out:
# LibriSpeech

# %%
# !pwd
# Out:
# /content/drive/My Drive/case studies 2/raw_data

# %%
shutil.move(os.path.join(os.getcwd(), 'LibriSpeech'), os.path.join(os.getcwd(), 'dev_clean'))
# Out:
# '/content/drive/My Drive/case studies 2/raw_data/dev_clean'

# %%
# !sudo wget http://www.openslr.org/resources/12/dev-other.tar.gz
# Out:
# --2020-03-01 08:51:45--  http://www.openslr.org/resources/12/dev-other.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 314305928 (300M) [application/x-gzip]
# Saving to: ‘dev-other.tar.gz’
#
# dev-other.tar.gz    100%[===================>] 299.75M  9.97MB/s    in 33s
#
# 2020-03-01 08:52:19 (9.00 MB/s) - ‘dev-other.tar.gz’ saved [314305928/314305928]

# %%
# !ls
# Out:
# dev_clean  dev-other.tar.gz

# %%
# !sudo tar zxf dev-other.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev-other.tar.gz  LibriSpeech

# %%
shutil.move(os.path.join(os.getcwd(), 'LibriSpeech'), os.path.join(os.getcwd(), 'dev_other'))
# Out:
# '/content/drive/My Drive/case studies 2/raw_data/dev_other'

# %%
# !sudo rm -rf dev-other.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev_other

# %%
# !sudo wget http://www.openslr.org/resources/12/test-clean.tar.gz
# Out:
# --2020-03-01 08:56:06--  http://www.openslr.org/resources/12/test-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 346663984 (331M) [application/x-gzip]
# Saving to: ‘test-clean.tar.gz’
#
# test-clean.tar.gz   100%[===================>] 330.60M  9.84MB/s    in 37s
#
# 2020-03-01 08:56:43 (9.03 MB/s) - ‘test-clean.tar.gz’ saved [346663984/346663984]

# %%
# !ls
# Out:
# dev_clean  dev_other  test-clean.tar.gz

# %%
# !sudo tar zxf test-clean.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev_other  LibriSpeech  test-clean.tar.gz

# %%
shutil.move(os.path.join(os.getcwd(), 'LibriSpeech'), os.path.join(os.getcwd(), 'test_clean'))
# Out:
# '/content/drive/My Drive/case studies 2/raw_data/test_clean'

# %%
# !sudo rm -rf test-clean.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev_other  test_clean

# %%
# !sudo wget http://www.openslr.org/resources/12/test-other.tar.gz
# Out:
# --2020-03-01 08:59:49--  http://www.openslr.org/resources/12/test-other.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 328757843 (314M) [application/x-gzip]
# Saving to: ‘test-other.tar.gz’
#
# test-other.tar.gz   100%[===================>] 313.53M  9.17MB/s    in 37s
#
# 2020-03-01 09:00:27 (8.38 MB/s) - ‘test-other.tar.gz’ saved [328757843/328757843]

# %%
# !ls
# Out:
# dev_clean  dev_other  test_clean  test-other.tar.gz

# %%
# !sudo tar zxf test-other.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev_other  LibriSpeech  test_clean  test-other.tar.gz

# %%
shutil.move(os.path.join(os.getcwd(), 'LibriSpeech'), os.path.join(os.getcwd(), 'test_other'))
# Out:
# '/content/drive/My Drive/case studies 2/raw_data/test_other'

# %%
# !ls
# Out:
# dev_clean  dev_other  test_clean  test_other  test-other.tar.gz

# %%
# !sudo rm -rf test-other.tar.gz

# %%
# !sudo wget http://www.openslr.org/resources/12/train-clean-100.tar.gz
# Out:
# --2020-03-01 09:03:01--  http://www.openslr.org/resources/12/train-clean-100.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6387309499 (5.9G) [application/x-gzip]
# Saving to: ‘train-clean-100.tar.gz’
#
# train-clean-100.tar 100%[===================>]   5.95G  8.69MB/s    in 15m 9s
#
# 2020-03-01 09:18:11 (6.70 MB/s) - ‘train-clean-100.tar.gz’ saved [6387309499/6387309499]

# %%
# !ls
# Out:
# dev_clean  dev_other  test_clean  test_other  train-clean-100.tar.gz

# %%
# !sudo tar zxf train-clean-100.tar.gz

# %%
# !ls
# Out:
# dev_clean  LibriSpeech	test_other
# dev_other  test_clean	train-clean-100.tar.gz

# %%
shutil.move(os.path.join(os.getcwd(), 'LibriSpeech'), os.path.join(os.getcwd(), 'train-clean-100'))
# Out:
# '/content/drive/My Drive/case studies 2/raw_data/train-clean-100'

# %%
# !sudo rm -rf train-clean-100.tar.gz

# %%
# !ls
# Out:
# dev_clean  dev_other  test_clean  test_other  train-clean-100
